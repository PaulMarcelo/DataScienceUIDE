# %% [markdown]
# # Manejo de datos faltantes en ciencia de datos

# %% [markdown]
# ## 1. Introducción
# En ciencia de datos, el manejo de datos faltantes es uno de los retos más comunes al trabajar con información real. Los datos incompletos pueden aparecer por errores de captura, problemas de almacenamiento o porque simplemente ciertos valores no existen. Ignorar estos valores puede llevar a análisis erróneos, modelos poco confiables o incluso fallos en los algoritmos. Por eso, es fundamental aprender a identificar, visualizar y tratar los datos faltantes de manera adecuada.

# %% [markdown]
# ## ¿Qué es un dato faltante? (`None`, `np.nan`, `pd.NA`)
# En Python existen varias formas de representar datos faltantes o valores nulos. Las más comunes son:
#
# - `None`: Objeto nulo de Python, indica ausencia de valor.
# - `np.nan`: Valor especial de tipo flotante proporcionado por NumPy, representa "Not a Number".
# - `pd.NA`: Introducido en versiones recientes de pandas, es una forma general de representar datos faltantes para distintos tipos de datos.
#
# ### Ejemplo resuelto: Operaciones con valores faltantes

# %%
import numpy as np
import pandas as pd
# None
print(
    None or True,     # True
    None or False,    # False
    None == None,     # True
    None is None,     # True
    type(None),       # <class 'NoneType'>
    sep="\n"
)
# np.nan
print(
    np.nan or True,         # True
    np.nan or False,        # nan
    np.nan == np.nan,       # False
    np.nan is np.nan,       # True
    np.nan / 2,             # nan
    np.nan * 7,             # nan
    type(np.nan),           # <class 'float'>
    np.isnan(np.nan),       # True
    sep="\n"
)
# Out:
# True
# False
# True
# True
# <class 'NoneType'>
# nan
# nan
# False
# True
# nan
# nan
# <class 'float'>
# True

# %% [markdown]
# **Explicación:**
# - `None` se comporta como un valor nulo en Python puro.
# - `np.nan` es especial para cálculos numéricos y se propaga en operaciones matemáticas.
# - Comparar `np.nan` consigo mismo siempre devuelve `False`.
# - Para verificar si un valor es `np.nan` se debe usar `np.isnan()`.

# %% [markdown]
# ## Identificación de datos faltantes en DataFrames
# Las funciones principales para identificar valores faltantes en pandas son `isna()` y `isnull()`. Ambas hacen exactamente lo mismo.
#
# ### Ejemplo

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame({
    'A': [1, np.nan, 3, None, 5],
    'B': [np.nan, 2, None, 4, pd.NA]
})

print("DataFrame original:")
print(df)

print("\n¿Dónde hay datos faltantes?")
print(df.isna())

print("\n¿Hay diferencia usando isnull?")
print(df.isnull())
# Out:
# DataFrame original:
#      A     B
# 0  1.0   NaN
# 1  NaN     2
# 2  3.0  None
# 3  NaN     4
# 4  5.0  <NA>
#
# ¿Dónde hay datos faltantes?
#        A      B
# 0  False   True
# 1   True  False
# 2  False   True
# 3   True  False
# 4  False   True
#
# ¿Hay diferencia usando isnull?
#        A      B
# 0  False   True
# 1   True  False
# 2  False   True
# 3   True  False
# 4  False   True

# %% [markdown]
# **Explicación:**
# - `isna()` y `isnull()` devuelven un DataFrame booleano indicando la presencia de datos faltantes.

# %% [markdown]
# ## Conteo y resumen de datos faltantes
# Es importante no solo identificar, sino cuantificar los datos faltantes. Podemos usar `.sum()`, `.mean()` y `.info()` para esto.
#
# ### Ejemplo resuelto

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame({
    'A': [1, np.nan, 3, None, 5],
    'B': [np.nan, 2, None, 4, pd.NA]
})

print("Conteo de datos faltantes por columna:")
print(df.isna().sum())

print("\nPorcentaje de datos faltantes por columna:")
print(df.isna().mean() * 100)

print("\nResumen general del DataFrame:")
print(df.info())
# Out:
# Conteo de datos faltantes por columna:
# A    2
# B    3
# dtype: int64
#
# Porcentaje de datos faltantes por columna:
# A    40.0
# B    60.0
# dtype: float64
#
# Resumen general del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      float64
#  1   B       2 non-null      object
# dtypes: float64(1), object(1)
# memory usage: 212.0+ bytes
# None

# %% [markdown]
# **duplicated()** devuelve una serie booleana para identificar duplicados.

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %% [markdown]
# **Explicación:**
# - `.sum()` suma los valores `True` (equivalente a contar los nulos).
# - `.mean()` da el porcentaje de valores faltantes.
# - `.info()` muestra cuántos valores no nulos hay en cada columna.

# %% [markdown]
# ## Visualización de datos faltantes
# Visualizar los datos faltantes es muy útil para detectar patrones. Una de las librerías más usadas es `missingno`.
#
# ### Ejemplo

# %%
import missingno as msno
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'A': [1, np.nan, 3, None, 5, 6, np.nan, 8],
    'B': [np.nan, 2, None, 4, pd.NA, 6, 7, 8],
    'C': [1, 2, 3, 4, 5, None, 7, np.nan]
})

msno.matrix(df)
# Out:
# <Axes: >

# %%
import numpy as np
print("-"*50)
print("Generación de datos faltantes aleatorios")
print("-"*50)
data = np.random.randint(1, 100, size=(8, 8))
df_aletorio = pd.DataFrame(data, columns=[f'Col{i}' for i in range(1, 9)])
for item in range(15):
    i = np.random.randint(0, 8)
    j = np.random.randint(0, 8)
    df_aletorio.iloc[i, j] = np.nan

print(df_aletorio)
print("-"*50)
print("Grafica")
print("-"*50)
msno.matrix(df_aletorio)
# Out:
# --------------------------------------------------
# Generación de datos faltantes aleatorios
# --------------------------------------------------
#    Col1  Col2  Col3  Col4  Col5  Col6  Col7  Col8
# 0  91.0  97.0  85.0  43.0  77.0    28    87   NaN
# 1  45.0  71.0   8.0  57.0   7.0    89    13  87.0
# 2   NaN  99.0   NaN  75.0  49.0    94    11   NaN
# 3   NaN  49.0   NaN  67.0   NaN    31    96  28.0
# 4   NaN  62.0  13.0   NaN  18.0     8    28  78.0
# 5  28.0  79.0  71.0  82.0  30.0    57    61  38.0
# 6  77.0   NaN  40.0   NaN   NaN    16    87  50.0
# 7   NaN  51.0   9.0  74.0   NaN    30    15  25.0
# --------------------------------------------------
# Grafica
# --------------------------------------------------
# <Axes: >

# %% [markdown]
# **Explicación:**
# - `msno.matrix(df)` muestra un gráfico donde las líneas blancas indican valores faltantes en el DataFrame.

# %% [markdown]
# ## Estrategias para el manejo de datos faltantes
# Las estrategias principales son:
# - **Eliminación de filas o columnas:** cuando hay muchos datos faltantes y no es crítico perder esa información.
# - **Imputación:** reemplazar los valores faltantes por la media, mediana, moda u otros valores.
#
# ### Ejemplo resuelto: Eliminación de datos faltantes

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'A': [1, np.nan, 3, None, 5],
    'B': [np.nan, 2, None, 4, pd.NA]
})

print("Original:")
print(df)

print("\nElimina filas con algún dato faltante:")
print(df.dropna())

print("\nElimina columnas donde todos los valores son faltantes:")
print(df.dropna(axis=1, how='all'))
# Out:
# Original:
#      A     B
# 0  1.0   NaN
# 1  NaN     2
# 2  3.0  None
# 3  NaN     4
# 4  5.0  <NA>
#
# Elimina filas con algún dato faltante:
# Empty DataFrame
# Columns: [A, B]
# Index: []
#
# Elimina columnas donde todos los valores son faltantes:
#      A     B
# 0  1.0   NaN
# 1  NaN     2
# 2  3.0  None
# 3  NaN     4
# 4  5.0  <NA>

# %% [markdown]
# ### Ejemplo: Imputación de datos

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'A': [1, np.nan, 3, None, 5],
    'B': [np.nan, 2, None, 4, None],
    'C':[np.nan, 2, None, 4, None]
})

print(df)
print("Imputa valores faltantes con la media:")

print(df.fillna(df.mean(numeric_only=True)))
# Out:
#      A    B    C
# 0  1.0  NaN  NaN
# 1  NaN  2.0  2.0
# 2  3.0  NaN  NaN
# 3  NaN  4.0  4.0
# 4  5.0  NaN  NaN
# Imputa valores faltantes con la media:
#      A    B    C
# 0  1.0  3.0  3.0
# 1  3.0  2.0  2.0
# 2  3.0  3.0  3.0
# 3  3.0  4.0  4.0
# 4  5.0  3.0  3.0

# %%
print("-"*50)
print(" Valores originales")
print("-"*50)
print(df_aletorio)
print("\n")

print("-"*50)
print("Eliminación filas con valores faltantes")
print(df_aletorio.dropna())
print("\n")

print("-"*50)
print("\nElimina columnas donde todos los valores son faltantes:")
print(df_aletorio.dropna(axis=1, how='all'))
print("\n")

df_imp_mean = df_aletorio.fillna(df_aletorio.mean(numeric_only=True))
print("-"*50)
print(" Imputación de datos con la media")
print("-"*50)
print(df_imp_mean)
print("\n")

df_imp_std = df_aletorio.fillna(df_aletorio.std(numeric_only=True))
# obtiene la desviacion estandar global y la aplica a todas las columnas
print("-"*50)
print(" Imputación de datos con la desviación estandar")
print("-"*50)
print(df_imp_std)

df_imp_std_2 = df_aletorio.apply(lambda x: x.fillna(x.std()))
# obtiene la desviacion estandar columna por columna y la aplica a sus valores
print("-"*50)
print(" Imputación de datos con la desviación estandar")
print("-"*50)
# Out:
# --------------------------------------------------
#  Valores originales
# --------------------------------------------------
#    Col1  Col2  Col3  Col4  Col5  Col6  Col7  Col8
# 0  58.0   NaN   NaN   NaN  14.0  19.0  79.0  79.0
# 1  21.0  72.0  56.0  45.0  92.0   NaN  16.0  88.0
# 2  76.0   NaN  30.0  96.0   NaN   5.0  29.0   NaN
# 3  50.0  50.0  88.0  58.0  81.0  42.0  91.0   NaN
# 4  48.0   NaN  21.0  39.0  65.0   NaN  23.0  80.0
# 5  75.0  35.0  41.0  39.0  22.0  35.0   NaN  43.0
# 6  45.0  42.0  28.0  49.0  11.0  69.0  18.0   4.0
# 7   NaN  88.0  30.0   NaN  76.0  67.0  94.0  61.0
#
#
# --------------------------------------------------
# Eliminación filas con valores faltantes
#    Col1  Col2  Col3  Col4  Col5  Col6  Col7  Col8
# 6  45.0  42.0  28.0  49.0  11.0  69.0  18.0   4.0
#
#
# --------------------------------------------------
#
# Elimina columnas donde todos los valores son faltantes:
#    Col1  Col2  Col3  Col4  Col5  Col6  Col7  Col8
# 0  58.0   NaN   NaN   NaN  14.0  19.0  79.0  79.0
# 1  21.0  72.0  56.0  45.0  92.0   NaN  16.0  88.0
# 2  76.0   NaN  30.0  96.0   NaN   5.0  29.0   NaN
# 3  50.0  50.0  88.0  58.0  81.0  42.0  91.0   NaN
# 4  48.0   NaN  21.0  39.0  65.0   NaN  23.0  80.0
# 5  75.0  35.0  41.0  39.0  22.0  35.0   NaN  43.0
# 6  45.0  42.0  28.0  49.0  11.0  69.0  18.0   4.0
# 7   NaN  88.0  30.0   NaN  76.0  67.0  94.0  61.0
#
#
# --------------------------------------------------
#  Imputación de datos con la media
# --------------------------------------------------
#         Col1  Col2  Col3       Col4       Col5  Col6  Col7       Col8
# 0  58.000000  57.4  42.0  54.333333  14.000000  19.0  79.0  79.000000
# 1  21.000000  72.0  56.0  45.000000  92.000000  39.5  16.0  88.000000
# 2  76.000000  57.4  30.0  96.000000  51.571429   5.0  29.0  59.166667
# 3  50.000000  50.0  88.0  58.000000  81.000000  42.0  91.0  59.166667
# 4  48.000000  57.4  21.0  39.000000  65.000000  39.5  23.0  80.000000
# 5  75.000000  35.0  41.0  39.000000  22.000000  35.0  50.0  43.000000
# 6  45.000000  42.0  28.0  49.000000  11.000000  69.0  18.0   4.000000
# 7  53.285714  88.0  30.0  54.333333  76.000000  67.0  94.0  61.000000
#
#
# --------------------------------------------------
#  Imputación de datos con la desviación estandar
# --------------------------------------------------
#         Col1       Col2       Col3       Col4       Col5       Col6  \
# 0  58.000000  22.040871  23.230727  21.611725  14.000000  19.000000
# 1  21.000000  72.000000  56.000000  45.000000  92.000000  25.547994
# 2  76.000000  22.040871  30.000000  96.000000  34.664377   5.000000
# 3  50.000000  50.000000  88.000000  58.000000  81.000000  42.000000
# 4  48.000000  22.040871  21.000000  39.000000  65.000000  25.547994
# 5  75.000000  35.000000  41.000000  39.000000  22.000000  35.000000
# 6  45.000000  42.000000  28.000000  49.000000  11.000000  69.000000
# 7  18.971156  88.000000  30.000000  21.611725  76.000000  67.000000
#
#         Col7      Col8
# 0  79.000000  79.00000
# 1  16.000000  88.00000
# 2  29.000000  31.51772
# 3  91.000000  31.51772
# 4  23.000000  80.00000
# 5  36.073998  43.00000
# 6  18.000000   4.00000
# 7  94.000000  61.00000
# --------------------------------------------------
#  Imputación de datos con la desviación estandar
# --------------------------------------------------

# %% [markdown]
# ## Advertencias comunes y buenas prácticas
# Trabajar con datos faltantes puede provocar errores sutiles o resultados inesperados. Ten en cuenta:
# - El uso de `==` para comparar `np.nan` nunca es True, siempre usa `np.isnan()` o `.isna()`.
# - Imputar valores puede introducir sesgos si no se justifica.
# - Algunas funciones de pandas y sklearn no funcionan con datos faltantes, otras sí.
#
# ### Ejemplo resuelto: Comparación de np.nan

# %%
import numpy as np

a = np.nan
b = np.nan

print("¿a == b?", a == b)
print("np.isnan(a):", np.isnan(a))
print("np.isnan(b):", np.isnan(b))
print("np.isnan(a) == np.isnan(b):", (np.isnan(a))==(np.isnan(b)))
# Out:
# ¿a == b? False
# np.isnan(a): True
# np.isnan(b): True
# np.isnan(a) == np.isnan(b): True

# %% [markdown]
# ### Ejemplo: Operaciones con datos faltantes

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({'A': [1, np.nan, 3, 4]})
print("Suma ignorando NaN:", df['A'].sum())
print("Promedio ignorando NaN:", df['A'].mean())
print("Cuenta total:", df['A'].count())
# Out:
# Suma ignorando NaN: 8.0
# Promedio ignorando NaN: 2.6666666666666665
# Cuenta total: 3

# %% [markdown]
# ## Caso práctico con un conjunto de datos real
# Vamos a cargar un conjunto de datos real (por ejemplo, algún dataset de Kaggle o de sklearn) y analizar el manejo de datos faltantes.
#
# ### Ejemplo: Dataset Titanic de seaborn

# %%
import seaborn as sns
import pandas as pd

df = sns.load_dataset('titanic')
print(df.head())
print(df.isna().sum())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# ## Vamos a extender el uso de una librería especifica para datos faltante
#
# ### MissingMethods

# %%
# !pip install upsetplot
# Out:
# Collecting upsetplot
#   Downloading UpSetPlot-0.9.0.tar.gz (23 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.11/dist-packages (from upsetplot) (2.2.2)
# Requirement already satisfied: matplotlib>=2.0 in /usr/local/lib/python3.11/dist-packages (from upsetplot) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0->upsetplot) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0->upsetplot) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0->upsetplot) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0->upsetplot) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0->upsetplot) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0->upsetplot) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0->upsetplot) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0->upsetplot) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0->upsetplot) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.23->upsetplot) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.23->upsetplot) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=2.0->upsetplot) (1.17.0)
# Building wheels for collected packages: upsetplot
#   Building wheel for upsetplot (pyproject.toml) ... done
#   Created wheel for upsetplot: filename=upsetplot-0.9.0-py3-none-any.whl size=24866 sha256=7aaec68c63a143980a821b7ed0da89ec16ea6bcbc7b622cda865d453593a8e6c
#   Stored in directory: /root/.cache/pip/wheels/7b/ce/88/1d0bce5b2680165c29c3e68416325e79674d5a9f422d037996
# Successfully built upsetplot
# Installing collected packages: upsetplot
# Successfully installed upsetplot-0.9.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# La extensión **missing_extension** amplía pandas para un análisis más profundo de los datos faltantes, proporcionando tablas, resúmenes y visualizaciones rápidas.

# %%
from missing_extension import MissingMethods

# %% [markdown]
# ## Resumen de Datos faltantes
# La función missing_variable_table muestra el número de valores faltantes agrupados por variable

# %%
df.missing.missing_variable_table()
# Out:
#    n_missing_in_variable  n_variables  pct_variables
# 0                      0           11      73.333333
# 1                      2            2      13.333333
# 2                    177            1       6.666667
# 3                    688            1       6.666667

# %%
# numero total de valores completos
df.missing.number_complete()
# Out:
# np.int64(12496)

# %%
#Numero total de valores faltantes
df.missing.number_missing()
# Out:
# np.int64(869)

# %% [markdown]
# ### Ejercicio para el estudiante
# Elige una columna con datos faltantes y aplica al menos dos estrategias diferentes de manejo (eliminación e imputación), luego analiza el impacto en el DataFrame.

# %%
import pandas as pd
import seaborn as sns

df = sns.load_dataset('titanic')

# tu código aquí
#Elige una columna con datos faltantes y aplica al menos dos estrategias diferentes de manejo (eliminación e imputación),
#luego analiza el impacto en el DataFrame.
df['age'].missing.missing_variable_table()
print(df)
print("-"*50)
print(" Eliminacion de datos")
print("-"*50)
df_age = df['age'].dropna()
print(df_age)
print("-"*50)
print(" Imputacion de datos")
print("-"*50)
df_age_2 = df['age'].fillna(df.mean(numeric_only=True))
print(df_age_2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3455491645.py in <cell line: 0>()
#       7 #Elige una columna con datos faltantes y aplica al menos dos estrategias diferentes de manejo (eliminación e imputación),
#       8 #luego analiza el impacto en el DataFrame.
# ----> 9 df['age'].missing.missing_variable_table()
#      10 print(df)
#      11 print("-"*50)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'Series' object has no attribute 'missing'

# %% [markdown]
# #Resumenes tabulares de valores faltantes
#
# Variables = Columnas
# Resumen por variable

# %%
df.missing.missing_variable_summary()
# Out:
#        variable  n_missing  n_cases  pct_missing
# 0      survived          0      891     0.000000
# 1        pclass          0      891     0.000000
# 2           sex          0      891     0.000000
# 3           age        177      891    19.865320
# 4         sibsp          0      891     0.000000
# 5         parch          0      891     0.000000
# 6          fare          0      891     0.000000
# 7      embarked          2      891     0.224467
# 8         class          0      891     0.000000
# 9           who          0      891     0.000000
# 10   adult_male          0      891     0.000000
# 11         deck        688      891    77.216611
# 12  embark_town          2      891     0.224467
# 13        alive          0      891     0.000000
# 14        alone          0      891     0.000000

# %% [markdown]
# ### Resumenes por caso
#
# Permite evaluar el numero de valores faltantes por fila.

# %%
df.missing.missing_case_summary()
# Out:
#      case  n_missing  pct_missing
# 0       0          1     5.882353
# 1       1          0     0.000000
# 2       2          1     5.882353
# 3       3          0     0.000000
# 4       4          1     5.882353
# ..    ...        ...          ...
# 886   886          1     5.882353
# 887   887          0     0.000000
# 888   888          2    11.764706
# 889   889          0     0.000000
# 890   890          1     5.882353
#
# [891 rows x 3 columns]

# %% [markdown]
# ### Intervalos de valores Faltantes
# Podemos trabajar datos faltantes por bloques span me indica un intervalo que identifica en xbloque cuantos valores faltante y copletos tenemos

# %%
(
    df
    .missing
    .missing_variable_span(
        variable="age",
        span_every=20. # que cantidad de bloques
    )
)
# Out:
#     span_counter  n_missing  n_complete  pct_missing  pct_complete
# 0              0          3          17    15.000000     85.000000
# 1              1          6          14    30.000000     70.000000
# 2              2          6          14    30.000000     70.000000
# 3              3          4          16    20.000000     80.000000
# 4              4          3          17    15.000000     85.000000
# 5              5          3          17    15.000000     85.000000
# 6              6          3          17    15.000000     85.000000
# 7              7          4          16    20.000000     80.000000
# 8              8          3          17    15.000000     85.000000
# 9              9          6          14    30.000000     70.000000
# 10            10          2          18    10.000000     90.000000
# 11            11          3          17    15.000000     85.000000
# 12            12          4          16    20.000000     80.000000
# 13            13          5          15    25.000000     75.000000
# 14            14          3          17    15.000000     85.000000
# 15            15          5          15    25.000000     75.000000
# 16            16          4          16    20.000000     80.000000
# 17            17          5          15    25.000000     75.000000
# 18            18          4          16    20.000000     80.000000
# 19            19          2          18    10.000000     90.000000
# 20            20          5          15    25.000000     75.000000
# 21            21          4          16    20.000000     80.000000
# 22            22          5          15    25.000000     75.000000
# 23            23          5          15    25.000000     75.000000
# 24            24          5          15    25.000000     75.000000
# 25            25          4          16    20.000000     80.000000
# 26            26          6          14    30.000000     70.000000
# 27            27          3          17    15.000000     85.000000
# 28            28          6          14    30.000000     70.000000
# 29            29          5          15    25.000000     75.000000
# 30            30          5          15    25.000000     75.000000
# 31            31          3          17    15.000000     85.000000
# 32            32          5          15    25.000000     75.000000
# 33            33          3          17    15.000000     85.000000
# 34            34          3          17    15.000000     85.000000
# 35            35          3          17    15.000000     85.000000
# 36            36          4          16    20.000000     80.000000
# 37            37          1          19     5.000000     95.000000
# 38            38          6          14    30.000000     70.000000
# 39            39          4          16    20.000000     80.000000
# 40            40          1          19     5.000000     95.000000
# 41            41          6          14    30.000000     70.000000
# 42            42          3          17    15.000000     85.000000
# 43            43          3          17    15.000000     85.000000
# 44            44          1          10     9.090909     90.909091

# %% [markdown]
# ### Racha de valores faltantes o Run length de valores faltantes

# %%
(
    df
    .missing
    .missing_variable_run(
        variable="age"
    )
)
# Out:
#      run_length     is_na
# 0             5  complete
# 1             1   missing
# 2            11  complete
# 3             1   missing
# 4             1  complete
# ..          ...       ...
# 298           9  complete
# 299           1   missing
# 300           9  complete
# 301           1   missing
# 302           2  complete
#
# [303 rows x 2 columns]

# %% [markdown]
# # Visualización inicial de valores faltantes
#
# Por Variable

# %%
df.missing.missing_variable_plot()

# %% [markdown]
# ## Visualizaciones de data faltante por fila

# %%
(
    df
    .missing
    .missing_variable_span_plot(
        variable="age",
        span_every=40,
        rot=0
    )
)

# %%
import missingno
missingno.bar(df = df)
# Out:
# <Axes: >

# %% [markdown]
# ## Visualización de data faltante por fila y columna

# %%
missingno.matrix(df=df)
# Out:
# <Axes: >

# %% [markdown]
# ## upsetplot()
# Premite evaluar que variables comparten valores faltantes, muestra la cantidad de valores faltantes y hace una comparación al final entre cada una

# %%
(
    df
    .missing
    .missing_upsetplot(
        #variables=None
        variables = ['age','embarked','embark_town', 'deck'],
        element_size = 60
    )
)
# Out:
# /usr/local/lib/python3.11/dist-packages/upsetplot/plotting.py:795: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["linewidth"].fillna(1, inplace=True)
# /usr/local/lib/python3.11/dist-packages/upsetplot/plotting.py:796: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["facecolor"].fillna(self._facecolor, inplace=True)
# /usr/local/lib/python3.11/dist-packages/upsetplot/plotting.py:797: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["edgecolor"].fillna(styles["facecolor"], inplace=True)
# /usr/local/lib/python3.11/dist-packages/upsetplot/plotting.py:798: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["linestyle"].fillna("solid", inplace=True)
# {'matrix': <Axes: >,
#  'shading': <Axes: >,
#  'totals': <Axes: >,
#  'intersections': <Axes: ylabel='Intersection size'>}

# %% [markdown]
# #Codificación de valores faltantes

# %% [markdown]
# 🚧 Advertencia
#
#   Al igual que cada persona es una nueva puerta a un mundo diferente, los valores faltantes existen en diferentes formas y colores. Al trabajar con valores faltantes será crítico entender sus distintas representaciones. A pesar de que el conjunto de datos de trabajo pareciera que no contiene valores faltantes, deberás ser capaz de ir más allá de lo observado a simple vista para remover el manto tras el cual se esconde lo desconocido.

# %% [markdown]
# ## Valores comúnmente asociados a valores faltantes en cadenas de texto

# %%
common_na_strings = (
    "missing",
    "NA",
    "N A",
    "N/A",
    "#N/A",
    "NA ",
    " NA",
    "N /A",
    "N / A",
    " N / A",
    "N / A ",
    "na",
    "n a",
    "n/a",
    "na ",
    " na",
    "n /a",
    "n / a",
    " a / a",
    "n / a ",
    "NULL",
    "null",
    "",
    "?",
    "*",
    ".",
)

# %% [markdown]
# ## Valores comúnmente asociados a valores faltantes en numeros

# %%
common_na_numbers = (-9, -99, -999, -9999, 9999, 66, 77, 88, -1)

# %% [markdown]
# #¿Cómo encontrar los valores comúnmente asociados a valores faltantes?

# %%
missing_data_example_df = pd.DataFrame.from_dict(
    dict(
        x = [1, 3, "NA", -99, -98, -99],
        y = ["A", "N/A", "NA", "E", "F", "G"],
        z = [-100, -99, -98, -101, -1, -1]
    )
)
missing_data_example_df
# Out:
#      x    y    z
# 0    1    A -100
# 1    3  N/A  -99
# 2   NA   NA  -98
# 3  -99    E -101
# 4  -98    F   -1
# 5  -99    G   -1

# %%
missing_data_example_df.missing.number_missing()
# Out:
# np.int64(0)

# %% [markdown]
# ### Revisar Valores únicos del DataFrame
#
# De esta forma se puede ver cuales son nuestros valores unicos y evaluar valores que son faltantes realmente.
#
# - En la primeralinea por columan
# - En la segunda de todo del set de datos

# %%
missing_data_example_df.x.unique()
# Out:
# array([1, 3, 'NA', -99, -98], dtype=object)

# %%
#Permite evaluar las columnas de tipo objetc y obtener sus valores únicos

(
    missing_data_example_df
    .select_dtypes(object)
    .apply(pd.unique)
)
# Out:
# x     [1, 3, NA, -99, -98]
# y    [A, N/A, NA, E, F, G]
# dtype: object

# %% [markdown]
# #Sustituyendo valores comúnmente asociados a valores faltantes

# %% [markdown]
# **Sustitución Global**
#
# Implica que realizas la sustitucion posterior al análisis o iteración de los datos

# %%
(
    missing_data_example_df
    .replace(
        to_replace=[-99,'NA'],
        value=np.nan
    )
)
# Out:
# /tmp/ipython-input-884111965.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .replace(
#       x    y      z
# 0   1.0    A -100.0
# 1   3.0  N/A    NaN
# 2   NaN  NaN  -98.0
# 3   NaN    E -101.0
# 4 -98.0    F   -1.0
# 5   NaN    G   -1.0

# %% [markdown]
# **Sustitución Dirigida**
#
# Nos permite agregar ciertas reglas de sustitución para una columan en específico

# %% [markdown]
# ### 9.1. Resumen de variables con datos faltantes: `missing_variable_summary()`

# %%
(
    missing_data_example_df
    .replace(
        to_replace={
            "x": {
                -99: np.nan
            },
           "z": {
                -99: np.nan
            }
        }
    )
)
# Out:
#      x    y      z
# 0    1    A -100.0
# 1    3  N/A    NaN
# 2   NA   NA  -98.0
# 3  NaN    E -101.0
# 4  -98    F   -1.0
# 5  NaN    G   -1.0

# %%
missing_data_example_df
# Out:
#      x    y    z
# 0    1    A -100
# 1    3  N/A  -99
# 2   NA   NA  -98
# 3  -99    E -101
# 4  -98    F   -1
# 5  -99    G   -1

# %%
(
    missing_data_example_df
    .replace(
        to_replace={
            "x": {
                "NA" :0
            },
            "y": {
                "N/A": np.nan,
                "NA" :np.nan
            },
           "z": {
                -101: np.nan
            }
        }
    )
)


missing_data_example_df_2 = (
    missing_data_example_df
    .replace({
        "y": ["N/A", "NA", "", " "],
        "z": [-101, -999]
    }, np.nan)
    .replace(r'^\s*$', np.nan, regex=True)  # Limpiar strings vacíos globalmente
)
# Out:
# /tmp/ipython-input-3286320745.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .replace(
#     x    y      z
# 0   1    A -100.0
# 1   3  NaN  -99.0
# 2   0  NaN  -98.0
# 3 -99    E    NaN
# 4 -98    F   -1.0
# 5 -99    G   -1.0

# %%
completas = df.missing.number_complete()
print(f"Filas completas (sin ningún dato faltante): {completas}")
# Out:
# Filas completas (sin ningún dato faltante): 12496

# %% [markdown]
# #Concepto y aplicación de la matriz de sombras (shadow matrix)
#
# La **matriz de sombras** (o **shadow matrix**) es un concepto utilizado en el análisis de datos y estadísticas para representar la presencia o ausencia de datos en un conjunto de datos. Este tipo de matriz ayuda a visualizar y analizar los patrones de datos faltantes, facilitando el entendimiento de cómo y por qué los datos faltan.
#
# ### Concepto de Matriz de Sombras
#
# La matriz de sombras es una representación binaria del conjunto de datos original donde:
#
# - **1** (o cualquier valor positivo) indica la presencia de un valor en esa posición del conjunto de datos original.
#
# - **0** (o cualquier valor negativo) indica la ausencia de un valor en esa posición.
#
# ### Uso y Beneficios
#
# 1. **Visualización de Datos Faltantes**:
#
# - La matriz de sombras facilita la visualización de patrones en los datos faltantes. Puedes ver claramente qué filas o columnas tienen más datos faltantes y si hay patrones específicos.
#
# 2. **Análisis de Patrones de Datos Faltantes**:
#
# - Ayuda a identificar si los datos faltantes están distribuidos aleatoriamente o si siguen algún patrón específico.
#
# 3. **Preprocesamiento**:
#
# - La matriz de sombras se utiliza en técnicas de imputación para entender cómo los datos faltantes están relacionados con otras variables y para mejorar los métodos de imputación.

# %% [markdown]
# ##Construcción de la matriz de sombras

# %%
(
    df
    #Genero una matriz de booleanos que me identifica con tru y false para que ,e puedan indicar cuales sno faltantes
    .isna()
    #Se remplaza para tener una matriz de datos con data más informativa
    .replace({
        False: "Not missing",
        True: "Missing"
    })
    # se debe tener nombres coordinados entre las variables originales y estas que se crean para ello se agrega el sufijo _NA
    .add_suffix("_NA")
    #concatenamos la matriz original con esta matriz de sommbras que acabamos de crear
    .pipe(
        lambda shadow_matrix: pd.concat(
            [df, shadow_matrix],
            axis="columns"
        )
    )
)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  ...     parch_NA      fare_NA  embarked_NA     class_NA  \
# 0      man  ...  Not missing  Not missing  Not missing  Not missing
# 1    woman  ...  Not missing  Not missing  Not missing  Not missing
# 2    woman  ...  Not missing  Not missing  Not missing  Not missing
# 3    woman  ...  Not missing  Not missing  Not missing  Not missing
# 4      man  ...  Not missing  Not missing  Not missing  Not missing
# ..     ...  ...          ...          ...          ...          ...
# 886    man  ...  Not missing  Not missing  Not missing  Not missing
# 887  woman  ...  Not missing  Not missing  Not missing  Not missing
# 888  woman  ...  Not missing  Not missing  Not missing  Not missing
# 889    man  ...  Not missing  Not missing  Not missing  Not missing
# 890    man  ...  Not missing  Not missing  Not missing  Not missing
#
#           who_NA adult_male_NA      deck_NA embark_town_NA     alive_NA  \
# 0    Not missing   Not missing      Missing    Not missing  Not missing
# 1    Not missing   Not missing  Not missing    Not missing  Not missing
# 2    Not missing   Not missing      Missing    Not missing  Not missing
# 3    Not missing   Not missing  Not missing    Not missing  Not missing
# 4    Not missing   Not missing      Missing    Not missing  Not missing
# ..           ...           ...          ...            ...          ...
# 886  Not missing   Not missing      Missing    Not missing  Not missing
# 887  Not missing   Not missing  Not missing    Not missing  Not missing
# 888  Not missing   Not missing      Missing    Not missing  Not missing
# 889  Not missing   Not missing  Not missing    Not missing  Not missing
# 890  Not missing   Not missing      Missing    Not missing  Not missing
#
#         alone_NA
# 0    Not missing
# 1    Not missing
# 2    Not missing
# 3    Not missing
# 4    Not missing
# ..           ...
# 886  Not missing
# 887  Not missing
# 888  Not missing
# 889  Not missing
# 890  Not missing
#
# [891 rows x 30 columns]

# %% [markdown]
# **Automatizando la generación de la matriz**

# %%
(
    df
    .missing
    .bind_shadow_matrix(only_missing = True) # only_missing = True toma en cuenta unicamente las variables que tienen valores faltantes
)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone       age_NA  \
# 0      man        True  NaN  Southampton    no  False  Not Missing
# 1    woman       False    C    Cherbourg   yes  False  Not Missing
# 2    woman       False  NaN  Southampton   yes   True  Not Missing
# 3    woman       False    C  Southampton   yes  False  Not Missing
# 4      man        True  NaN  Southampton    no   True  Not Missing
# ..     ...         ...  ...          ...   ...    ...          ...
# 886    man        True  NaN  Southampton    no   True  Not Missing
# 887  woman       False    B  Southampton   yes   True  Not Missing
# 888  woman       False  NaN  Southampton    no  False      Missing
# 889    man        True    C    Cherbourg   yes   True  Not Missing
# 890    man        True  NaN   Queenstown    no   True  Not Missing
#
#      embarked_NA      deck_NA embark_town_NA
# 0    Not Missing      Missing    Not Missing
# 1    Not Missing  Not Missing    Not Missing
# 2    Not Missing      Missing    Not Missing
# 3    Not Missing  Not Missing    Not Missing
# 4    Not Missing      Missing    Not Missing
# ..           ...          ...            ...
# 886  Not Missing      Missing    Not Missing
# 887  Not Missing  Not Missing    Not Missing
# 888  Not Missing      Missing    Not Missing
# 889  Not Missing  Not Missing    Not Missing
# 890  Not Missing      Missing    Not Missing
#
# [891 rows x 19 columns]

# %% [markdown]
# ###  Visualización de valores faltantes
# `missing_extension` puede hacer gráficos para visualizar los patrones de ausencia en variables y casos.

# %%
(
    df
    .missing
    .bind_shadow_matrix(only_missing = True)
    .pipe(
        lambda df1:(
            sns.displot(
                data=df1,
                x="age",
                hue="pclass",
                kind="kde"
            )
        )
    )
)

# %%
(
    df
    .missing
    .bind_shadow_matrix(only_missing = True)
    .pipe(
        lambda df:(
            sns.boxenplot(
                data=df,
                x="pclass",
                y="age",
            )
        )
    )
)
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %% [markdown]
# ## Correlación de Nulidad

# %% [markdown]
# **Existen valores faltantes que aparecen conjuntamente con otras variables en el conjunto de datos?**
#
# La correlacion de nulidad nos ayuda a encontrar relaciones entre las variables en funcion de su nulidad
#
# Los valores coloreados de color gris representan que no hay una correlacion ni positiva ni negativa entre las valores faltantes de las variables
#
# Los valores coloreados de azul indican una correlacion positiva, es decir, la presencia de un valor faltante en una de las variables esta correlacionado con un valor faltante en la otra.
#
# Los valores coloreados de rojo simboliza una correlacion negativa, es decir, mientras en una de las variables hay un valor faltante en la otro se tiene un valor completo y vicerversa.
#
# Hay caso donde te puedes encontrar un simbolo de <1 lo que indica que estas cerca del 100% de correlacion bien sea negativa o positiva dependiendo del color

# %%
missingno.heatmap(
    df=df
)
# Out:
# <Axes: >

# %% [markdown]
# ## Dendograma
#
# El dendrograma muestra cómo se agrupan las variables según su patrón de datos faltantes. En otras palabras:
#
# - Variables que están unidas más cercanamente (ramas cortas) tienden a tener valores faltantes en los mismos registros (filas).
#
# - Variables más separadas tienen patrones distintos de valores ausentes.

# %%
missingno.dendrogram(
    df=df
)
# Out:
# <Axes: >

# %% [markdown]
# ## Conclusiones y recomendaciones
# El manejo adecuado de datos faltantes es crucial para obtener análisis confiables y modelos predictivos robustos. Siempre debes:
# - Analizar las causas de los datos faltantes
# - Visualizar patrones de ausencia
# - Justificar cualquier estrategia de imputación o eliminación
# - Documentar las decisiones tomadas
