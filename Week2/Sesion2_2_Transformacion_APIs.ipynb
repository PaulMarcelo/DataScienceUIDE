# %% [markdown]
# # 🧠 Sesión 2.2: Transformación de Datos y Consumo de APIs

# %% [markdown]
# ### 🎯 Objetivos:
# - Realizar transformaciones complejas en `pandas`
# - Aplicar funciones personalizadas
# - Consumir y analizar datos desde APIs públicas
# - Resolver ejercicios de análisis y visualización de datos

# %% [markdown]
# ## 🔧 1. Librerías necesarias

# %%
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='whitegrid')

# %% [markdown]
# ## 📊 2. Cargar dataset base, agrupamiento y funciones estadísticas (`groupby`)

# %%
url_csv='https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv'


# Cargar nuevamente el dataset 'tips'
df_tips = pd.read_csv(url_csv)
df_tips.columns = [col.lower().strip() for col in df_tips.columns] #elimnacion de espacios
# Aseguramos que no haya nulos para el análisis
df_tips.dropna(inplace=True)

# Agrupar por día y calcular estadísticas básicas de 'total_bill'
agrupado_por_dia = df_tips.groupby('day')['total_bill'].agg(['count', 'mean', 'sum'])
print("Agrupamiento por día (total_bill):")
print(agrupado_por_dia)
# Out:
# Agrupamiento por día (total_bill):
#       count       mean      sum
# day
# Fri      19  17.151579   325.88
# Sat      87  20.441379  1778.40
# Sun      76  21.410000  1627.16
# Thur     62  17.682742  1096.33

# %% [markdown]
# Usamos `groupby('day')` para agrupar filas por el día de la semana y luego `agg()` para calcular el conteo, la media y la suma del `total_bill` para cada día.

# %% [markdown]
# ### **Tarea Adicional para el Estudiante (Compartir Código y Criterios):**
#
# *   **Agrupamiento Múltiple:** Agrupa los datos por `day` y `sex` y calcula la propina (`tip`) promedio y máxima para cada combinación.
# *   ¿Cómo interpretarías los resultados que obtienes para el día 'Sat' y 'Sun' comparados con 'Fri' y 'Thur'? ¿Qué insights podrías extraer sobre los hábitos de gasto?

# %%
# Tu código de agrupamiento múltiple y comentarios aquí
agrupado_por_dia = df_tips.groupby(['day','sex'])['tip'].agg(['mean', 'max'])
agrupado_por_dia
# Out:
#                  mean    max
# day  sex
# Fri  Female  2.781111   4.30
#      Male    2.693000   4.73
# Sat  Female  2.801786   6.50
#      Male    3.083898  10.00
# Sun  Female  3.367222   5.20
#      Male    3.220345   6.50
# Thur Female  2.575625   5.17
#      Male    2.980333   6.70

# %% [markdown]
# ## 🧪 Ordenamiento, Filtrado y Condiciones

# %%
# Ordenar el DataFrame por 'total_bill' de forma descendente
df_ordenado = df_tips.sort_values(by='total_bill', ascending=False)
print("Dataset ordenado por total_bill (primeras 5 filas):")
print(df_ordenado.head())

# Filtrar por total_bill mayor a 40
filtro_alto_gasto = df_ordenado[df_ordenado['total_bill'] > 40]
print("\nClientes con gasto mayor a $40:")
print(filtro_alto_gasto)
# Out:
# Dataset ordenado por total_bill (primeras 5 filas):
#      total_bill    tip   sex smoker  day    time  size
# 170       50.81  10.00  Male    Yes  Sat  Dinner     3
# 212       48.33   9.00  Male     No  Sat  Dinner     4
# 59        48.27   6.73  Male     No  Sat  Dinner     4
# 156       48.17   5.00  Male     No  Sun  Dinner     6
# 182       45.35   3.50  Male    Yes  Sun  Dinner     3
#
# Clientes con gasto mayor a $40:
#      total_bill    tip     sex smoker   day    time  size
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4
# 142       41.19   5.00    Male     No  Thur   Lunch     5
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4

# %% [markdown]
# Hemos ordenado los datos para ver los gastos más altos y luego filtrado para aislar a los clientes que gastaron más de $40.

# %% [markdown]
# ### **Tarea Adicional para el Estudiante (Compartir Código y Criterios):**
#
# *   **Filtro Combinado:** Crea un nuevo DataFrame que contenga solo las filas donde:
#     1.  El `day` sea 'Sat' O 'Sun'.
#     2.  Y la `tip` sea mayor a $5.
#     3. Muestra las primeras 5 filas de este nuevo DataFrame.
# *   Si quisieras identificar a los clientes que fueron "generosos" (tip > $3) y también vinieron en un día concurrido (day in ['Sat', 'Sun']), ¿cómo combinarías las condiciones?

# %%
# Tu código de filtro combinado y comentarios aquí
print("Tip>5 y dia concurrido Sat, Sun")
new_df_1 = df_tips[(df_tips['day'].isin(['Sat', 'Sun'])) & (df_tips['tip'] > 5)]
display(new_df_1.head())
print("Tip>3 y dia concurrido Sat, Sun")
new_df_2 = df_tips[(df_tips['day'].isin(['Sat', 'Sun'])) & (df_tips['tip'] > 3)]
display(new_df_2.head())
# Out:
# Tip>5 y dia concurrido Sat, Sun
#     total_bill   tip     sex smoker  day    time  size
# 23       39.42  7.58    Male     No  Sat  Dinner     4
# 44       30.40  5.60    Male     No  Sun  Dinner     4
# 47       32.40  6.00    Male     No  Sun  Dinner     4
# 52       34.81  5.20  Female     No  Sun  Dinner     4
# 59       48.27  6.73    Male     No  Sat  Dinner     4
# Tip>3 y dia concurrido Sat, Sun
#    total_bill   tip     sex smoker  day    time  size
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 7       26.88  3.12    Male     No  Sun  Dinner     4

# %% [markdown]
# ## 🧪 Crear Columnas con `apply()` y Funciones Lambda/Definidas

# %%
q1 = df_tips['tip'].quantile(0.25)
q3 = df_tips['tip'].quantile(0.75)

def clasificar_tip(x):
    if x < q1:
        return 'Baja'
    elif x > q3:
        return 'Alta'
    else:
        return 'Media'

df_tips['clasificacion_propina'] = df_tips['tip'].apply(clasificar_tip) # aplica la funcion a cada elemento de la columna tip
print("\nDataset con columna de clasificación de propina:")
print(df_tips[['tip', 'clasificacion_propina']].head())
# Out:
# Dataset con columna de clasificación de propina:
#     tip clasificacion_propina
# 0  1.01                  Baja
# 1  1.66                  Baja
# 2  3.50                 Media
# 3  3.31                 Media
# 4  3.61                  Alta

# %%
resumen = df_tips.groupby(['day', 'clasificacion_propina'])['total_bill'].agg(['mean', 'count'])
resumen
# Out:
#                                  mean  count
# day  clasificacion_propina
# Fri  Alta                   27.923333      3
#      Baja                   10.448000      5
#      Media                  17.260909     11
# Sat  Alta                   28.602105     19
#      Baja                   12.963333     18
#      Media                  20.032400     50
# Sun  Alta                   26.218400     25
#      Baja                   12.633333      9
#      Media                  20.428571     42
# Thur Alta                   27.770000     14
#      Baja                   11.542308     13
#      Media                  15.928571     35

# %%
# Definir una función más compleja
def relacion_gasto_propina(row):
    return row['tip'] / row['total_bill']

# Aplicar la función a cada fila usando axis=1
df_tips['ratio_propina_gasto'] = df_tips.apply(relacion_gasto_propina, axis=1)
print("\nDataset con ratio propina/gasto:")
print(df_tips[['total_bill', 'tip', 'ratio_propina_gasto']].head())
# Out:
# Dataset con ratio propina/gasto:
#    total_bill   tip  ratio_propina_gasto
# 0       16.99  1.01             0.059447
# 1       10.34  1.66             0.160542
# 2       21.01  3.50             0.166587
# 3       23.68  3.31             0.139780
# 4       24.59  3.61             0.146808

# %% [markdown]
# Usamos `apply()` para crear nuevas columnas basadas en condiciones o cálculos de otras columnas, tanto con lambdas como con funciones definidas.

# %% [markdown]
# ### **Tarea Adicional para el Estudiante (Compartir Código y Criterios):**
#
# *   **Categorización del Ratio de Propina:** Crea una nueva columna llamada `nivel_propina` que categorice el `ratio_propina_gasto` de la siguiente manera:
#     *   'Muy Alto' si `ratio_propina_gasto` > 0.2
#     *   'Alto' si `ratio_propina_gasto` > 0.15
#     *   'Medio' si `ratio_propina_gasto` > 0.10
#     *   'Bajo' en cualquier otro caso.
# *   ¿Qué otras variables podrías crear a partir de las existentes para obtener nuevos insights (ej. propina por persona, porcentaje de propina sobre el total)?

# %%
# Tu código para la nueva columna de categorización y comentarios aquí
df_tips['nivel_propina'] = df_tips['ratio_propina_gasto'].apply(
      lambda x: 'Muy Alto' if x > 0.2 else ('Alto' if x > 0.15 else ('Medio' if x > 0.10 else 'Bajo')))
df_tips

print("Resultados")
display(df_tips.head())

#bill_per_person
df_tips['tip_per_person'] = df_tips['tip'] / df_tips['size']
df_tips['tip_per_person']
# Out:
# Resultados
#    total_bill   tip     sex smoker  day    time  size clasificacion_propina  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2                  Baja
# 1       10.34  1.66    Male     No  Sun  Dinner     3                  Baja
# 2       21.01  3.50    Male     No  Sun  Dinner     3                 Media
# 3       23.68  3.31    Male     No  Sun  Dinner     2                 Media
# 4       24.59  3.61  Female     No  Sun  Dinner     4                  Alta
#
#    ratio_propina_gasto nivel_propina  bill_per_person  tip_per_person
# 0             0.059447          Bajo         8.495000        0.505000
# 1             0.160542          Alto         3.446667        0.553333
# 2             0.166587          Alto         7.003333        1.166667
# 3             0.139780         Medio        11.840000        1.655000
# 4             0.146808         Medio         6.147500        0.902500

# %% [markdown]
# ## 🧪 Pivot y Melt para Reorganizar Datos

# %%
# Crear una tabla dinámica (pivot_table)
# Índice: 'sex', Columnas: 'day', Valores: promedio de 'tip'
pivot_table_sex_dia = df_tips.pivot_table(index='sex', columns='day', values='tip', aggfunc='mean')
print("Pivot table: Promedio de propina por sexo y día:")
print(pivot_table_sex_dia)
# Out:
# Pivot table: Promedio de propina por sexo y día:
# day          Fri       Sat       Sun      Thur
# sex
# Female  2.781111  2.801786  3.367222  2.575625
# Male    2.693000  3.083898  3.220345  2.980333

# %%
# Volver al formato largo con melt
melted_pivot = pivot_table_sex_dia.reset_index().melt(id_vars='sex', var_name='dia', value_name='propina_promedio')
print("\nDatos en formato 'melted' (largo):")
print(melted_pivot.head())
# Out:
# Datos en formato 'melted' (largo):
#       sex  dia  propina_promedio
# 0  Female  Fri          2.781111
# 1    Male  Fri          2.693000
# 2  Female  Sat          2.801786
# 3    Male  Sat          3.083898
# 4  Female  Sun          3.367222

# %% [markdown]
# ### **Tarea Adicional para el Estudiante (Compartir Código y Criterios):**
#
# *   **Pivot con Múltiples Columnas y Agregaciones:** Crea un `pivot_table` que tenga:
#     *   Índice: `sex`
#     *   Columnas: `day`
#     *   Valores: `total_bill` y `tip`
#     *   Agregaciones: `mean` para `total_bill` y `sum` para `tip`.
# *   ¿En qué tipo de análisis sería útil usar `pivot_table` y `melt`? Proporciona un breve ejemplo conceptual.

# %%
# Tu código para el pivot table avanzado y comentarios aquí
pivot_table_sex_dia_multiple = df_tips.pivot_table(index='sex', columns='day',
                                                   values=['total_bill','tip'],
                                                   aggfunc={'total_bill':'mean', 'tip':'sum'})
pivot_table_sex_dia_multiple
print("\nDatos nueva tabla pivot:")
print(pivot_table_sex_dia_multiple.head())

#----
#melted_pivot = pivot_table_sex_dia_multiple.reset_index().melt(id_vars='sex', var_name='dia',
 #                                                              value_name=['total_bill','tip'])

#pivot_table_sex_dia_multiple.columns.names = ['value_type', 'day']  # Asegura nombres correctos
#pivot_reset = pivot_table_sex_dia_multiple.reset_index()

#melted = pivot_reset.melt(id_vars='sex',
 #                         var_name=['value_type', 'day'],
  #                        value_name='value')

#print("\nDatos en formato 'melted' (largo):")
#print(melted.head())
# Out:
# Datos nueva tabla pivot:
#           tip                        total_bill                        \
# day       Fri     Sat     Sun   Thur        Fri        Sat        Sun
# sex
# Female  25.03   78.45   60.61  82.42  14.145556  19.680357  19.872222
# Male    26.93  181.95  186.78  89.41  19.857000  20.802542  21.887241
#
#
# day          Thur
# sex
# Female  16.715312
# Male    18.714667

# %% [markdown]
# ## 📊 3: Visualización de la clasificación de propinas

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(data=df_tips, x='nivel_propina', y='total_bill')
plt.title('Distribución del total de la cuenta según categoría de propina')
plt.show()

# %% [markdown]
# ## 🌐 4. Consumo de APIs y Transformaciones

# %% [markdown]
# ## 🧪 Consumo de API de Clima (Open-Meteo)

# %%
import pandas as pd

# URL para datos de clima en Quito
url_quito = "https://api.open-meteo.com/v1/forecast?latitude=-0.23&longitude=-78.52&daily=temperature_2m_max,temperature_2m_min&timezone=auto"
response_quito = requests.get(url_quito)

print(f"Código de estado para Quito: {response_quito.status_code}")

if response_quito.status_code == 200:
    data_quito = response_quito.json()
    df_clima_quito = pd.DataFrame(data_quito['daily'])
    print("\nDatos de clima de Quito (primeras 5 filas):")
    print(df_clima_quito.head())
else:
    print("Error al obtener datos de la API de clima para Quito.")
# Out:
# Código de estado para Quito: 200
#
# Datos de clima de Quito (primeras 5 filas):
#          time  temperature_2m_max  temperature_2m_min
# 0  2025-07-26                17.5                 8.1
# 1  2025-07-27                18.5                 9.4
# 2  2025-07-28                17.4                 8.8
# 3  2025-07-29                18.0                 9.1
# 4  2025-07-30                17.3                 7.9

# %%
# URL para datos de clima en Guayaquil
url_gye = "https://api.open-meteo.com/v1/forecast?latitude=-2.19616&longitude=-79.88621&daily=temperature_2m_max,temperature_2m_min&timezone=auto"
response_gye = requests.get(url_gye)

print(f"\nCódigo de estado para Guayaquil: {response_gye.status_code}")

if response_gye.status_code == 200:
    data_gye = response_gye.json()
    df_clima_gye = pd.DataFrame(data_gye['daily'])
    print("\nDatos de clima de Guayaquil (primeras 5 filas):")
    print(df_clima_gye.head())
else:
    print("Error al obtener datos de la API de clima para Guayaquil.")
# Out:
# Código de estado para Guayaquil: 200
#
# Datos de clima de Guayaquil (primeras 5 filas):
#          time  temperature_2m_max  temperature_2m_min
# 0  2025-07-26                28.6                20.5
# 1  2025-07-27                27.3                20.3
# 2  2025-07-28                30.4                20.7
# 3  2025-07-29                28.1                20.8
# 4  2025-07-30                28.7                20.2

# %% [markdown]
# Usamos la librería `requests` para hacer llamadas a APIs y `pd.DataFrame()` para convertir la respuesta JSON a un formato tabular.

# %% [markdown]
# ### **Tarea Adicional para el Estudiante (Compartir Código y Criterios):**
#
# *   **Comparación de Temperaturas:** Calcula la temperatura promedio máxima y mínima para Quito y Guayaquil a partir de los DataFrames `df_clima_quito` y `df_clima_gye`.
# *   ¿Qué otros parámetros podrías pasar a la URL de la API de Open-Meteo para obtener información adicional (ej. `current_weather`, `hourly`)? ¿Cómo procesarías esos datos si fueran listas anidadas?

# %%
# Tu código de comparación de temperaturas y comentarios aquí
temp_mean_quito_max = round(df_clima_quito['temperature_2m_max'].mean(), ndigits=2)
temp_mean_quito_min = round(df_clima_quito['temperature_2m_min'].mean(), ndigits=2)
print(f"Temperatura promedio máxima en Quito: {temp_mean_quito_max}")
print(f"Temperatura promedio minima en Quito: {temp_mean_quito_min}")
temp_mean_gye_max = round(df_clima_gye['temperature_2m_max'].mean(), ndigits=2)
temp_mean_gye_min = round(df_clima_gye['temperature_2m_min'].mean(), ndigits=2)
print(f"Temperatura promedio máxima en Guayaquil: {temp_mean_gye_max}")
print(f"Temperatura promedio minima en Guayaquil: {temp_mean_gye_min}")
# Out:
# Temperatura promedio máxima en Quito: 17.93
# Temperatura promedio minima en Quito: 8.74
# Temperatura promedio máxima en Guayaquil: 29.14
# Temperatura promedio minima en Guayaquil: 20.54

# %%
# URL para datos de clima en Guayaquil
url_gye_2 = "https://api.open-meteo.com/v1/forecast?latitude=-2.19616&longitude=-79.88621&daily=temperature_2m_max,temperature_2m_min&current_weather=true&hourly=temperature_2m,precipitation,windspeed_10m&timezone=auto"
response_gye_2 = requests.get(url_gye_2)

print(f"\nCódigo de estado para Guayaquil: {response_gye_2.status_code}")

if response_gye_2.status_code == 200:
    data_gye_2 = response_gye_2.json()
    #print(df_clima_gye)
    df_clima_gye_2 = pd.DataFrame(data_gye_2['hourly'])
    print("\nDatos de clima de Guayaquil (primeras 5 filas):")
    print(df_clima_gye_2.head())
else:
    print("Error al obtener datos de la API de clima para Guayaquil.")
# Out:
# Código de estado para Guayaquil: 200
#
# Datos de clima de Guayaquil (primeras 5 filas):
#                time  temperature_2m  precipitation  windspeed_10m
# 0  2025-07-26T00:00            21.2            0.0           11.4
# 1  2025-07-26T01:00            21.2            0.0           11.4
# 2  2025-07-26T02:00            21.1            0.0            9.7
# 3  2025-07-26T03:00            21.0            0.0            8.4
# 4  2025-07-26T04:00            20.8            0.0            8.2

# %% [markdown]
# ## 🧪 Consumo de API de Usuarios (JSONPlaceholder) y Procesamiento Estructurado

# %%
json_api_url_users = 'https://jsonplaceholder.typicode.com/users'

# Leer directamente con pandas
df_users = pd.read_json(json_api_url_users)

# Procesar la columna 'address' para aplanarla
df_users['calle'] = df_users['address'].apply(lambda x: x.get('street'))
df_users['ciudad'] = df_users['address'].apply(lambda x: x.get('city'))
df_users['zipcode'] = df_users['address'].apply(lambda x: x.get('zipcode'))

print("Datos de usuarios con dirección aplanada:")
display(df_users[['name', 'email', 'calle', 'ciudad', 'zipcode']].head())

# Agrupar por ciudad y contar usuarios
usuarios_por_ciudad = df_users.groupby('ciudad').size().reset_index(name='numero_usuarios')
print("\nNúmero de usuarios por ciudad:")
display(usuarios_por_ciudad)
# Out:
# Datos de usuarios con dirección aplanada:
#                name                      email              calle  \
# 0     Leanne Graham          Sincere@april.biz        Kulas Light
# 1      Ervin Howell          Shanna@melissa.tv      Victor Plains
# 2  Clementine Bauch         Nathan@yesenia.net  Douglas Extension
# 3  Patricia Lebsack  Julianne.OConner@kory.org        Hoeger Mall
# 4  Chelsey Dietrich   Lucio_Hettinger@annie.ca       Skiles Walks
#
#           ciudad     zipcode
# 0    Gwenborough  92998-3874
# 1    Wisokyburgh  90566-7771
# 2  McKenziehaven  59590-4157
# 3    South Elvis  53919-4257
# 4     Roscoeview       33263
# Número de usuarios por ciudad:
#            ciudad  numero_usuarios
# 0       Aliyaview                1
# 1  Bartholomebury                1
# 2     Gwenborough                1
# 3       Howemouth                1
# 4     Lebsackbury                1
# 5   McKenziehaven                1
# 6      Roscoeview                1
# 7   South Christy                1
# 8     South Elvis                1
# 9     Wisokyburgh                1

# %% [markdown]
# Aplanamos la columna `address` para poder usarla en agrupaciones. Luego, contamos cuántos usuarios hay en cada ciudad.

# %% [markdown]
# ### **Tarea Adicional para el Estudiante (Compartir Código y Criterios):**
#
# *   **Información de la Compañía:** La columna `company` en la API de usuarios también contiene un diccionario con información (nombre, catchPhrase). Extrae el `name` de la compañía y la `catchPhrase` en nuevas columnas. Luego, cuenta cuántos usuarios trabajan en cada compañía.
# *   ¿Qué tipo de preguntas podrías responder usando la información de la compañía y la localización de los usuarios?

# %%
# Tu código para procesar la columna company y comentarios aquí
df_users['name_comp'] = df_users['company'].apply(lambda x: x.get('name'))
df_users['catchPhrase_comp'] = df_users['company'].apply(lambda x: x.get('catchPhrase'))
print("Datos compañia")
display(df_users[['name_comp', 'catchPhrase_comp']].head())

# Cuántos usuarios trabajan en cada compañía.
#user_per_company = df_users.groupby('name_comp').value_counts()
user_per_company = df_users.groupby('name_comp').size().reset_index(name='numero_usuarios')
print("\nNúmero de usuarios por compañía:")
display(user_per_company)

# Cuántos usuarios viven en cada calle
df_users['name_street'] = df_users['address'].apply(lambda x: x.get('street'))
user_per_street = df_users.groupby('name_street').size().reset_index(name='numero_usuarios')
print("\nNúmero de usuarios por nombre de calle:")
display(user_per_street)
# Out:
# Datos compañia
#             name_comp                          catchPhrase_comp
# 0     Romaguera-Crona    Multi-layered client-server neural-net
# 1        Deckow-Crist            Proactive didactic contingency
# 2  Romaguera-Jacobson         Face to face bifurcated interface
# 3       Robel-Corkery  Multi-tiered zero tolerance productivity
# 4         Keebler LLC      User-centric fault-tolerant solution
# Número de usuarios por compañía:
#             name_comp  numero_usuarios
# 0     Abernathy Group                1
# 1   Considine-Lockman                1
# 2        Deckow-Crist                1
# 3          Hoeger LLC                1
# 4         Johns Group                1
# 5         Keebler LLC                1
# 6       Robel-Corkery                1
# 7     Romaguera-Crona                1
# 8  Romaguera-Jacobson                1
# 9       Yost and Sons                1
# Número de usuarios por nombre de calle:
#          name_street  numero_usuarios
# 0         Dayna Park                1
# 1  Douglas Extension                1
# 2   Ellsworth Summit                1
# 3        Hoeger Mall                1
# 4    Kattie Turnpike                1
# 5        Kulas Light                1
# 6  Norberto Crossing                1
# 7          Rex Trail                1
# 8       Skiles Walks                1
# 9      Victor Plains                1

# %% [markdown]
# ## 🧪 Consumo de API de Salud (GHO API)

# %%
# URL para datos de Esperanza de Vida al Nacer (ejemplo de datos anidados)
# Nota: Esta API puede cambiar o tener diferentes endpoints. Usamos un ejemplo típico.
# La estructura de respuesta de esta API suele ser más compleja con paginación y filtros.
# Para simplificar, usaremos un ejemplo teórico de cómo manejar una respuesta anidada.

# Suponiendo que obtenemos una respuesta JSON con una estructura similar a esto:
# {
#   "@odata.context": "...",
#   "value": [
#     {"IndicatorCode": "WHOSIS_000001", "Location": "Indonesia", "Dim1Value": "Female", "TimeDimValue": "2018", "NumericValue": 69.4},
#     {"IndicatorCode": "WHOSIS_000001", "Location": "Indonesia", "Dim1Value": "Male", "TimeDimValue": "2018", "NumericValue": 68.7},
#     {"IndicatorCode": "WHOSIS_000001", "Location": "Bhutan", "Dim1Value": "Female", "TimeDimValue": "2018", "NumericValue": 72.7},
#     ...
#   ]
# }


# Simulemos la obtención del DataFrame para el ejemplo práctico
data_simulada_salud = {
    "value": [
        {"IndicatorCode": "WHOSIS_000001", "Location": "Ecuador", "Dim1Value": "Female", "TimeDimValue": "2018", "NumericValue": 69.4},
        {"IndicatorCode": "WHOSIS_000001", "Location": "Ecuador", "Dim1Value": "Male", "TimeDimValue": "2018", "NumericValue": 68.7},
        {"IndicatorCode": "WHOSIS_000001", "Location": "Colombia", "Dim1Value": "Female", "TimeDimValue": "2018", "NumericValue": 72.7},
        {"IndicatorCode": "WHOSIS_000001", "Location": "Colombia", "Dim1Value": "Male", "TimeDimValue": "2002", "NumericValue": 67.1},
        {"IndicatorCode": "WHOSIS_000001", "Location": "Peru", "Dim1Value": "Female", "TimeDimValue": "2015", "NumericValue": 76.1},
        {"IndicatorCode": "WHOSIS_000001", "Location": "Peru", "Dim1Value": "Male", "TimeDimValue": "2015", "NumericValue": 75.8},
    ]
}
df_salud = pd.DataFrame(data_simulada_salud['value'])

print("Datos simulados de Esperanza de Vida al Nacer (primeras 5 filas):")
print(df_salud.head())
print("\nColumnas disponibles:", df_salud.columns)
# Out:
# Datos simulados de Esperanza de Vida al Nacer (primeras 5 filas):
#    IndicatorCode  Location Dim1Value TimeDimValue  NumericValue
# 0  WHOSIS_000001   Ecuador    Female         2018          69.4
# 1  WHOSIS_000001   Ecuador      Male         2018          68.7
# 2  WHOSIS_000001  Colombia    Female         2018          72.7
# 3  WHOSIS_000001  Colombia      Male         2002          67.1
# 4  WHOSIS_000001      Peru    Female         2015          76.1
#
# Columnas disponibles: Index(['IndicatorCode', 'Location', 'Dim1Value', 'TimeDimValue',
#        'NumericValue'],
#       dtype='object')

# %% [markdown]
# ### **Tarea Adicional para el Estudiante (Compartir Código y Criterios):**
#
# *   **Análisis de Esperanza de Vida:**
#     1.  Renombra las columnas para que sean más legibles: `Location` -> `pais`, `Dim1Value` -> `sexo`, `TimeDimValue` -> `año`, `NumericValue` -> `esperanza_vida`.
#     2.  Calcula la esperanza de vida promedio para cada `pais`, considerando solo los datos del año 2018. Si no hay datos de 2018 para algún país, puedes ignorarlo o asignar un valor (ej. NaN).
# *  ¿Cómo podrías manejar datos que tienen múltiples años y sexos para un mismo país si quisieras hacer un análisis de tendencia a lo largo del tiempo?

# %%
# Tu código para el análisis de esperanza de vida y comentarios aquí
df_salud.rename(columns={'Location': 'pais', 'Dim1Value': 'sexo', 'TimeDimValue': 'año', 'NumericValue': 'esperanza_vida'}, inplace=True)
df_salud

# Datos del año 2018
df_salud_2018 = df_salud[df_salud['año'] == '2018']
#df_salud_2018

#Esperanza promedio
df_salud_2018.groupby('pais')['esperanza_vida'].mean()
# Out:
# pais
# Colombia    72.70
# Ecuador     69.05
# Name: esperanza_vida, dtype: float64

# %%
# En un caso real, necesitaríamos hacer una petición GET:
url_salud = "https://ghoapi.azureedge.net/api/WHOSIS_000001"
response_salud = requests.get(url_salud)
data_salud = response_salud.json()
df_salud = pd.DataFrame(data_salud['value'])

# %%
df_salud
# Out:
#              Id  IndicatorCode SpatialDimType SpatialDim ParentLocationCode  \
# 0       5471166  WHOSIS_000001        COUNTRY        SUR                AMR
# 1           856  WHOSIS_000001        COUNTRY        SOM                EMR
# 2          1045  WHOSIS_000001        COUNTRY        BTN               SEAR
# 3          3548  WHOSIS_000001        COUNTRY        BHR                EMR
# 4          6793  WHOSIS_000001        COUNTRY        SAU                EMR
# ...         ...            ...            ...        ...                ...
# 12931  10075562  WHOSIS_000001        COUNTRY        UGA                AFR
# 12932  10077027  WHOSIS_000001        COUNTRY        DZA                AFR
# 12933  10079901  WHOSIS_000001        COUNTRY        CHN                WPR
# 12934  10080069  WHOSIS_000001        COUNTRY        GUY                AMR
# 12935  10081448  WHOSIS_000001        COUNTRY        IRN                EMR
#
#       TimeDimType         ParentLocation Dim1Type  TimeDim      Dim1  ...  \
# 0            YEAR               Americas      SEX     2019  SEX_BTSX  ...
# 1            YEAR  Eastern Mediterranean      SEX     2008   SEX_MLE  ...
# 2            YEAR        South-East Asia      SEX     2002  SEX_BTSX  ...
# 3            YEAR  Eastern Mediterranean      SEX     2011  SEX_FMLE  ...
# 4            YEAR  Eastern Mediterranean      SEX     2005  SEX_FMLE  ...
# ...           ...                    ...      ...      ...       ...  ...
# 12931        YEAR                 Africa      SEX     2007  SEX_FMLE  ...
# 12932        YEAR                 Africa      SEX     2015  SEX_BTSX  ...
# 12933        YEAR        Western Pacific      SEX     2013  SEX_FMLE  ...
# 12934        YEAR               Americas      SEX     2002  SEX_FMLE  ...
# 12935        YEAR  Eastern Mediterranean      SEX     2011  SEX_BTSX  ...
#
#       DataSourceDim             Value NumericValue        Low       High  \
# 0              None  73.0 [72.6-73.4]    73.022859  72.626240  73.417393
# 1              None  48.0 [46.7-49.6]    48.037541  46.716784  49.628457
# 2              None  67.8 [67.1-68.6]    67.845665  67.083124  68.558745
# 3              None  75.2 [75.1-75.4]    75.205359  75.050478  75.385175
# 4              None  73.1 [72.8-73.5]    73.122274  72.806453  73.478948
# ...             ...               ...          ...        ...        ...
# 12931          None  59.0 [58.1-60.0]    59.008192  58.090032  59.956274
# 12932          None  76.1 [75.8-76.4]    76.069092  75.792205  76.413973
# 12933          None  79.1 [78.8-79.5]    79.070282  78.768764  79.460209
# 12934          None  67.8 [67.4-68.3]    67.763888  67.391640  68.255974
# 12935          None  76.9 [76.7-77.1]    76.871714  76.733712  77.080336
#
#       Comments                           Date  TimeDimensionValue  \
# 0         None  2024-08-02T09:43:39.193+02:00                2019
# 1         None  2024-08-02T09:43:39.193+02:00                2008
# 2         None  2024-08-02T09:43:39.193+02:00                2002
# 3         None  2024-08-02T09:43:39.193+02:00                2011
# 4         None  2024-08-02T09:43:39.193+02:00                2005
# ...        ...                            ...                 ...
# 12931     None  2024-08-02T09:43:39.193+02:00                2007
# 12932     None  2024-08-02T09:43:39.193+02:00                2015
# 12933     None  2024-08-02T09:43:39.193+02:00                2013
# 12934     None  2024-08-02T09:43:39.193+02:00                2002
# 12935     None  2024-08-02T09:43:39.193+02:00                2011
#
#               TimeDimensionBegin           TimeDimensionEnd
# 0      2019-01-01T00:00:00+01:00  2019-12-31T00:00:00+01:00
# 1      2008-01-01T00:00:00+01:00  2008-12-31T00:00:00+01:00
# 2      2002-01-01T00:00:00+01:00  2002-12-31T00:00:00+01:00
# 3      2011-01-01T00:00:00+01:00  2011-12-31T00:00:00+01:00
# 4      2005-01-01T00:00:00+01:00  2005-12-31T00:00:00+01:00
# ...                          ...                        ...
# 12931  2007-01-01T00:00:00+01:00  2007-12-31T00:00:00+01:00
# 12932  2015-01-01T00:00:00+01:00  2015-12-31T00:00:00+01:00
# 12933  2013-01-01T00:00:00+01:00  2013-12-31T00:00:00+01:00
# 12934  2002-01-01T00:00:00+01:00  2002-12-31T00:00:00+01:00
# 12935  2011-01-01T00:00:00+01:00  2011-12-31T00:00:00+01:00
#
# [12936 rows x 25 columns]

# %%
url = 'https://ghoapi.azureedge.net/api/WHOSIS_000001'
resp = requests.get(url)
data = resp.json()
data
# Out:
# {'@odata.context': 'https://ghoapi.azureedge.net/api/$metadata#WHOSIS_000001',
#  'value': [{'Id': 5471166,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'SUR',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2019,
#    'Dim1': 'SEX_BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '73.0 [72.6-73.4]',
#    'NumericValue': 73.02285851,
#    'Low': 72.62624037,
#    'High': 73.41739297,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2019',
#    'TimeDimensionBegin': '2019-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2019-12-31T00:00:00+01:00'},
#   {'Id': 856,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'SOM',
#    'ParentLocationCode': 'EMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Eastern Mediterranean',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2008,
#    'Dim1': 'SEX_MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '48.0 [46.7-49.6]',
#    'NumericValue': 48.03754082,
#    'Low': 46.71678387,
#    'High': 49.62845721,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2008',
#    'TimeDimensionBegin': '2008-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2008-12-31T00:00:00+01:00'},
#   {'Id': 1045,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BTN',
#    'ParentLocationCode': 'SEAR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'South-East Asia',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2002,
#    'Dim1': 'SEX_BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '67.8 [67.1-68.6]',
#    'NumericValue': 67.84566543,
#    'Low': 67.08312422,
#    'High': 68.55874474,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2002',
#    'TimeDimensionBegin': '2002-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2002-12-31T00:00:00+01:00'},
#   {'Id': 3548,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BHR',
#    'ParentLocationCode': 'EMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Eastern Mediterranean',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2011,
#    'Dim1': 'SEX_FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '75.2 [75.1-75.4]',
#    'NumericValue': 75.20535884,
#    'Low': 75.05047771,
#    'High': 75.38517504,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2011',
#    'TimeDimensionBegin': '2011-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2011-12-31T00:00:00+01:00'},
#   {'Id': 6793,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'SAU',
#    'ParentLocationCode': 'EMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Eastern Mediterranean',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2005,
#    'Dim1': 'SEX_FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '73.1 [72.8-73.5]',
#    'NumericValue': 73.12227378,
#    'Low': 72.80645298,
#    'High': 73.47894822,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2005',
#    'TimeDimensionBegin': '2005-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2005-12-31T00:00:00+01:00'},
#   {'Id': 7045,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'CYP',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2003,
#    'Dim1': 'SEX_MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '76.9 [76.7-77.2]',
#    'NumericValue': 76.86012885,
#    'Low': 76.67123665,
#    'High': 77.16347738,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2003',
#    'TimeDimensionBegin': '2003-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2003-12-31T00:00:00+01:00'},
#   {'Id': 7359,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'DNK',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2014,
#    'Dim1': 'SEX_MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '78.6 [78.6-78.7]',
#    'NumericValue': 78.61687489,
#    'Low': 78.59347689,
#    'High': 78.7057478,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2014',
#    'TimeDimensionBegin': '2014-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2014-12-31T00:00:00+01:00'},
#   {'Id': 8651,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'PHL',
#    'ParentLocationCode': 'WPR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2007,
#    'Dim1': 'SEX_BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '69.6 [69.3-70.0]',
#    'NumericValue': 69.58190674,
#    'Low': 69.27042318,
#    'High': 69.99117192,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2007',
#    'TimeDimensionBegin': '2007-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2007-12-31T00:00:00+01:00'},
#   {'Id': 9192,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'MAR',
#    'ParentLocationCode': 'EMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Eastern Mediterranean',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2020,
#    'Dim1': 'SEX_FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '73.9 [73.3-74.4]',
#    'NumericValue': 73.86985157,
#    'Low': 73.33215257,
#    'High': 74.42699856,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2020',
#    'TimeDimensionBegin': '2020-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2020-12-31T00:00:00+01:00'},
#   {'Id': 10149,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'WSM',
#    'ParentLocationCode': 'WPR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2004,
#    'Dim1': 'SEX_FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.1 [71.6-72.7]',
#    'NumericValue': 72.08095548,
#    'Low': 71.56647872,
#    'High': 72.73081838,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2004',
#    'TimeDimensionBegin': '2004-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2004-12-31T00:00:00+01:00'},
#   {'Id': 11497,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'JOR',
#    'ParentLocationCode': 'EMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Eastern Mediterranean',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2014,
#    'Dim1': 'SEX_MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '78.4 [78.0-78.9]',
#    'NumericValue': 78.39096907,
#    'Low': 77.9773549,
#    'High': 78.89185172,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2014',
#    'TimeDimensionBegin': '2014-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2014-12-31T00:00:00+01:00'},
#   {'Id': 12836,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'URY',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2015,
#    'Dim1': 'SEX_BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.1 [77.1-77.2]',
#    'NumericValue': 77.09925201,
#    'Low': 77.05355529,
#    'High': 77.20308276,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2015',
#    'TimeDimensionBegin': '2015-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2015-12-31T00:00:00+01:00'},
#   {'Id': 12839,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'DNK',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2020,
#    'Dim1': 'SEX_FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '83.2 [83.1-83.3]',
#    'NumericValue': 83.16166983,
#    'Low': 83.13841156,
#    'High': 83.25733665,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2020',
#    'TimeDimensionBegin': '2020-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2020-12-31T00:00:00+01:00'},
#   {'Id': 12885,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'PRI',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2020,
#    'Dim1': 'SEX_MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '76.1 [76.1-76.3]',
#    'NumericValue': 76.14090106,
#    'Low': 76.05102592,
#    'High': 76.30635768,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2020',
#    'TimeDimensionBegin': '2020-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2020-12-31T00:00:00+01:00'},
#   {'Id': 13989,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GHA',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2005,
#    'Dim1': 'SEX_MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.3 [57.7-59.0]',
#    'NumericValue': 58.2958344,
#    'Low': 57.73964597,
#    'High': 59.00903347,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2005',
#    'TimeDimensionBegin': '2005-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2005-12-31T00:00:00+01:00'},
#   {'Id': 14841,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'TON',
#    'ParentLocationCode': 'WPR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2019,
#    'Dim1': 'SEX_BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.9 [72.4-73.6]',
#    'NumericValue': 72.94212581,
#    'Low': 72.39303564,
#    'High': 73.64425455,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2019',
#    'TimeDimensionBegin': '2019-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2019-12-31T00:00:00+01:00'},
#   {'Id': 16443,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'JOR',
#    'ParentLocationCode': 'EMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Eastern Mediterranean',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2009,
#    'Dim1': 'SEX_FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '76.6 [76.2-76.9]',
#    'NumericValue': 76.55739127,
#    'Low': 76.24832572,
#    'High': 76.90901942,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2009',
#    'TimeDimensionBegin': '2009-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2009-12-31T00:00:00+01:00'},
#   {'Id': 16645,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'TUR',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2012,
#    'Dim1': 'SEX_MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '73.8 [73.4-74.2]',
#    'NumericValue': 73.77355049,
#    'Low': 73.35270086,
#    'High': 74.18741879,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2012',
#    'TimeDimensionBegin': '2012-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2012-12-31T00:00:00+01:00'},
#   {'Id': 17508,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BRA',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2003,
#    'Dim1': 'SEX_BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.3 [72.0-72.6]',
#    'NumericValue': 72.30491342,
#    'Low': 72.02894266,
#    'High': 72.58864374,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2003',
#    'TimeDimensionBegin': '2003-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2003-12-31T00:00:00+01:00'},
#   {'Id': 17600,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FJI',
#    'ParentLocationCode': 'WPR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2006,
#    'Dim1': 'SEX_BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '67.1 [66.8-67.4]',
#    'NumericValue': 67.08069927,
#    'Low': 66.83476265,
#    'High': 67.36102486,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2006',
#    'TimeDimensionBegin': '2006-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2006-12-31T00:00:00+01:00'},
#   {'Id': 18466,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'NIC',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2020,
#    'Dim1': 'SEX_MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '71.7 [71.4-72.1]',
#    'NumericValue': 71.71241065,
#    'Low': 71.39890481,
#    'High': 72.07787079,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2020',
#    'TimeDimensionBegin': '2020-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2020-12-31T00:00:00+01:00'},
#   {'Id': 19439,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'IRQ',
#    'ParentLocationCode': 'EMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Eastern Mediterranean',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2003,
#    'Dim1': 'SEX_MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '65.7 [64.9-66.6]',
#    'NumericValue': 65.68953983,
#    'Low': 64.89438575,
#    'High': 66.62662104,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2003',
#    'TimeDimensionBegin': '2003-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2003-12-31T00:00:00+01:00'},
#   {'Id': 20651,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BGD',
#    'ParentLocationCode': 'SEAR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'South-East Asia',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2017,
#    'Dim1': 'SEX_MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.1 [71.5-72.9]',
#    'NumericValue': 72.08322327,
#    'Low': 71.46217486,
#    'High': 72.89170185,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2017',
#    'TimeDimensionBegin': '2017-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2017-12-31T00:00:00+01:00'},
#   {'Id': 20826,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'TON',
#    'ParentLocationCode': 'WPR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2016,
#    'Dim1': 'SEX_BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.6 [71.9-73.2]',
#    'NumericValue': 72.56032607,
#    'Low': 71.92825937,
#    'High': 73.19726025,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2016',
#    'TimeDimensionBegin': '2016-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2016-12-31T00:00:00+01:00'},
#   {'Id': 20860,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'SWE',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2016,
#    'Dim1': 'SEX_MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '80.4 [80.4-80.4]',
#    'NumericValue': 80.36714012,
#    'Low': 80.36303372,
#    'High': 80.44718723,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2016',
#    'TimeDimensionBegin': '2016-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2016-12-31T00:00:00+01:00'},
#   {'Id': 21736,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'GLOBAL',
#    'SpatialDim': 'GLOBAL',
#    'ParentLocationCode': None,
#    'TimeDimType': 'YEAR',
#    'ParentLocation': None,
#    'Dim1Type': 'SEX',
#    'TimeDim': 2015,
#    'Dim1': 'SEX_BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.2 [71.7-72.7]',
#    'NumericValue': 72.18568947,
#    'Low': 71.71225781,
#    'High': 72.66885564,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2015',
#    'TimeDimensionBegin': '2015-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2015-12-31T00:00:00+01:00'},
#   {'Id': 22691,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AUS',
#    'ParentLocationCode': 'WPR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2006,
#    'Dim1': 'SEX_BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '81.0 [81.0-81.1]',
#    'NumericValue': 81.04245453,
#    'Low': 81.03700874,
#    'High': 81.11608627,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2006',
#    'TimeDimensionBegin': '2006-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2006-12-31T00:00:00+01:00'},
#   {'Id': 22945,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ISL',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2005,
#    'Dim1': 'SEX_BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '80.9 [80.8-81.1]',
#    'NumericValue': 80.90304444,
#    'Low': 80.80183544,
#    'High': 81.10646149,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2005',
#    'TimeDimensionBegin': '2005-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2005-12-31T00:00:00+01:00'},
#   {'Id': 22953,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'COD',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2018,
#    'Dim1': 'SEX_FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '63.6 [62.7-64.6]',
#    'NumericValue': 63.60932257,
#    'Low': 62.68629835,
#    'High': 64.59326208,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2018',
#    'TimeDimensionBegin': '2018-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2018-12-31T00:00:00+01:00'},
#   {'Id': 24169,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FSM',
#    'ParentLocationCode': 'WPR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2001,
#    'Dim1': 'SEX_BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '63.8 [63.2-64.5]',
#    'NumericValue': 63.81961029,
#    'Low': 63.18020379,
#    'High': 64.49686133,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2001',
#    'TimeDimensionBegin': '2001-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2001-12-31T00:00:00+01:00'},
#   {'Id': 24232,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'NGA',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2018,
#    'Dim1': 'SEX_MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.3 [60.1-62.4]',
#    'NumericValue': 61.26091993,
#    'Low': 60.11076654,
#    'High': 62.4237436,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2018',
#    'TimeDimensionBegin': '2018-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2018-12-31T00:00:00+01:00'},
#   {'Id': 24603,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'KEN',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2007,
#    'Dim1': 'SEX_BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.6 [57.7-59.2]',
#    'NumericValue': 58.55063756,
#    'Low': 57.73834102,
#    'High': 59.23246103,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2007',
#    'TimeDimensionBegin': '2007-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2007-12-31T00:00:00+01:00'},
#   {'Id': 24699,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ATG',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2016,
#    'Dim1': 'SEX_BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '75.5 [75.3-75.9]',
#    'NumericValue': 75.54812509,
#    'Low': 75.26119899,
#    'High': 75.85072805,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2016',
#    'TimeDimensionBegin': '2016-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2016-12-31T00:00:00+01:00'},
#   {'Id': 27051,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BWA',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2005,
#    'Dim1': 'SEX_MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '50.8 [49.6-52.2]',
#    'NumericValue': 50.84700013,
#    'Low': 49.64729021,
#    'High': 52.20969406,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2005',
#    'TimeDimensionBegin': '2005-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2005-12-31T00:00:00+01:00'},
#   {'Id': 27069,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'CYP',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2004,
#    'Dim1': 'SEX_FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '81.5 [81.3-81.8]',
#    'NumericValue': 81.50500335,
#    'Low': 81.33599663,
#    'High': 81.76925412,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2004',
#    'TimeDimensionBegin': '2004-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2004-12-31T00:00:00+01:00'},
#   {'Id': 27494,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'TUN',
#    'ParentLocationCode': 'EMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Eastern Mediterranean',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2013,
#    'Dim1': 'SEX_FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '79.1 [78.5-80.0]',
#    'NumericValue': 79.10734252,
#    'Low': 78.4865653,
#    'High': 79.95492648,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2013',
#    'TimeDimensionBegin': '2013-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2013-12-31T00:00:00+01:00'},
#   {'Id': 28742,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'CZE',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2017,
#    'Dim1': 'SEX_FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '81.7 [81.7-81.8]',
#    'NumericValue': 81.69092888,
#    'Low': 81.65996467,
#    'High': 81.80087964,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2017',
#    'TimeDimensionBegin': '2017-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2017-12-31T00:00:00+01:00'},
#   {'Id': 30379,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'PNG',
#    'ParentLocationCode': 'WPR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2011,
#    'Dim1': 'SEX_BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '65.0 [64.3-65.9]',
#    'NumericValue': 65.03278821,
#    'Low': 64.32389717,
#    'High': 65.91541809,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2011',
#    'TimeDimensionBegin': '2011-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2011-12-31T00:00:00+01:00'},
#   {'Id': 30987,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FRA',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2012,
#    'Dim1': 'SEX_FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '84.5 [84.5-84.6]',
#    'NumericValue': 84.52986176,
#    'Low': 84.47185824,
#    'High': 84.58786527,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2012',
#    'TimeDimensionBegin': '2012-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2012-12-31T00:00:00+01:00'},
#   {'Id': 30995,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ESP',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2016,
#    'Dim1': 'SEX_MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '80.0 [80.0-80.1]',
#    'NumericValue': 80.0420428,
#    'Low': 79.98194724,
#    'High': 80.10213836,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2016',
#    'TimeDimensionBegin': '2016-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2016-12-31T00:00:00+01:00'},
#   {'Id': 31668,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'JAM',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2011,
#    'Dim1': 'SEX_BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.9 [72.7-73.1]',
#    'NumericValue': 72.86139713,
#    'Low': 72.6861071,
#    'High': 73.10765661,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2011',
#    'TimeDimensionBegin': '2011-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2011-12-31T00:00:00+01:00'},
#   {'Id': 31835,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'SVK',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2020,
#    'Dim1': 'SEX_MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '73.5 [73.4-73.6]',
#    'NumericValue': 73.48147988,
#    'Low': 73.43699005,
#    'High': 73.60505041,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2020',
#    'TimeDimensionBegin': '2020-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2020-12-31T00:00:00+01:00'},
#   {'Id': 35587,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'WORLDBANKINCOMEGROUP',
#    'SpatialDim': 'WB_HI',
#    'ParentLocationCode': None,
#    'TimeDimType': 'YEAR',
#    'ParentLocation': None,
#    'Dim1Type': 'SEX',
#    'TimeDim': 2002,
#    'Dim1': 'SEX_BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.9 [77.9-78.0]',
#    'NumericValue': 77.91958141,
#    'Low': 77.90362021,
#    'High': 77.99571724,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2002',
#    'TimeDimensionBegin': '2002-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2002-12-31T00:00:00+01:00'},
#   {'Id': 36595,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'SWE',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2005,
#    'Dim1': 'SEX_MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '78.3 [78.3-78.4]',
#    'NumericValue': 78.31471805,
#    'Low': 78.31267054,
#    'High': 78.38802065,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2005',
#    'TimeDimensionBegin': '2005-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2005-12-31T00:00:00+01:00'},
#   {'Id': 37435,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'LBR',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2021,
#    'Dim1': 'SEX_FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '64.3 [62.8-65.4]',
#    'NumericValue': 64.26883806,
#    'Low': 62.83963072,
#    'High': 65.37267181,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2021',
#    'TimeDimensionBegin': '2021-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2021-12-31T00:00:00+01:00'},
#   {'Id': 38376,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'IRL',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2004,
#    'Dim1': 'SEX_MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '75.9 [75.9-76.0]',
#    'NumericValue': 75.93998811,
#    'Low': 75.91643091,
#    'High': 76.04515005,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2004',
#    'TimeDimensionBegin': '2004-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2004-12-31T00:00:00+01:00'},
#   {'Id': 39414,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'SUR',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2000,
#    'Dim1': 'SEX_BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '70.6 [70.2-71.0]',
#    'NumericValue': 70.55904903,
#    'Low': 70.22081576,
#    'High': 71.00143639,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2000',
#    'TimeDimensionBegin': '2000-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2000-12-31T00:00:00+01:00'},
#   {'Id': 40609,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'UZB',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2009,
#    'Dim1': 'SEX_BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '66.3 [66.0-66.6]',
#    'NumericValue': 66.2800996,
#    'Low': 65.97043394,
#    'High': 66.59868172,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2009',
#    'TimeDimensionBegin': '2009-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2009-12-31T00:00:00+01:00'},
#   {'Id': 41092,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'NZL',
#    'ParentLocationCode': 'WPR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2018,
#    'Dim1': 'SEX_FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '83.4 [83.3-83.4]',
#    'NumericValue': 83.36205057,
#    'Low': 83.32410343,
#    'High': 83.44852765,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2018',
#    'TimeDimensionBegin': '2018-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2018-12-31T00:00:00+01:00'},
#   {'Id': 43843,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GNB',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2014,
#    'Dim1': 'SEX_MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '54.7 [53.7-55.9]',
#    'NumericValue': 54.70521169,
#    'Low': 53.69402578,
#    'High': 55.86665143,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2014',
#    'TimeDimensionBegin': '2014-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2014-12-31T00:00:00+01:00'},
#   {'Id': 44857,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'OMN',
#    'ParentLocationCode': 'EMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Eastern Mediterranean',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2001,
#    'Dim1': 'SEX_FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '76.0 [75.5-76.7]',
#    'NumericValue': 76.00067092,
#    'Low': 75.45487758,
#    'High': 76.65899873,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2001',
#    'TimeDimensionBegin': '2001-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2001-12-31T00:00:00+01:00'},
#   {'Id': 45561,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'DJI',
#    'ParentLocationCode': 'EMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Eastern Mediterranean',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2012,
#    'Dim1': 'SEX_MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.2 [60.0-62.6]',
#    'NumericValue': 61.18324458,
#    'Low': 60.01778639,
#    'High': 62.5548227,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2012',
#    'TimeDimensionBegin': '2012-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2012-12-31T00:00:00+01:00'},
#   {'Id': 46189,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'REGION',
#    'SpatialDim': 'WPR',
#    'ParentLocationCode': None,
#    'TimeDimType': 'YEAR',
#    'ParentLocation': None,
#    'Dim1Type': 'SEX',
#    'TimeDim': 2016,
#    'Dim1': 'SEX_MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '73.9 [73.5-74.3]',
#    'NumericValue': 73.92346253,
#    'Low': 73.54226981,
#    'High': 74.32411083,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2016',
#    'TimeDimensionBegin': '2016-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2016-12-31T00:00:00+01:00'},
#   {'Id': 47209,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ECU',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2017,
#    'Dim1': 'SEX_BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.3 [77.0-77.7]',
#    'NumericValue': 77.31252311,
#    'Low': 76.98704781,
#    'High': 77.7151026,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2017',
#    'TimeDimensionBegin': '2017-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2017-12-31T00:00:00+01:00'},
#   {'Id': 48668,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'TTO',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2018,
#    'Dim1': 'SEX_MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '70.6 [70.3-70.9]',
#    'NumericValue': 70.59042495,
#    'Low': 70.33123238,
#    'High': 70.87131746,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2018',
#    'TimeDimensionBegin': '2018-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2018-12-31T00:00:00+01:00'},
#   {'Id': 48969,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'NZL',
#    'ParentLocationCode': 'WPR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2003,
#    'Dim1': 'SEX_BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '79.1 [79.0-79.1]',
#    'NumericValue': 79.05551434,
#    'Low': 79.02408803,
#    'High': 79.14850346,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2003',
#    'TimeDimensionBegin': '2003-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2003-12-31T00:00:00+01:00'},
#   {'Id': 49474,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'IND',
#    'ParentLocationCode': 'SEAR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'South-East Asia',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2018,
#    'Dim1': 'SEX_MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '68.9 [68.4-69.5]',
#    'NumericValue': 68.87555599,
#    'Low': 68.35001557,
#    'High': 69.47412105,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2018',
#    'TimeDimensionBegin': '2018-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2018-12-31T00:00:00+01:00'},
#   {'Id': 50291,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ALB',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2013,
#    'Dim1': 'SEX_BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.8 [77.3-78.3]',
#    'NumericValue': 77.77410839,
#    'Low': 77.32303546,
#    'High': 78.31119909,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2013',
#    'TimeDimensionBegin': '2013-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2013-12-31T00:00:00+01:00'},
#   {'Id': 50629,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'LSO',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2014,
#    'Dim1': 'SEX_MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '46.0 [44.9-47.4]',
#    'NumericValue': 46.03257198,
#    'Low': 44.8919612,
#    'High': 47.37528775,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2014',
#    'TimeDimensionBegin': '2014-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2014-12-31T00:00:00+01:00'},
#   {'Id': 50703,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'EST',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2001,
#    'Dim1': 'SEX_FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '76.5 [76.4-76.6]',
#    'NumericValue': 76.47111928,
#    'Low': 76.36928575,
#    'High': 76.62864887,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2001',
#    'TimeDimensionBegin': '2001-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2001-12-31T00:00:00+01:00'},
#   {'Id': 50911,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'CHL',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2005,
#    'Dim1': 'SEX_BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '78.0 [78.0-78.1]',
#    'NumericValue': 78.0049121,
#    'Low': 77.98583386,
#    'High': 78.0847708,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2005',
#    'TimeDimensionBegin': '2005-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2005-12-31T00:00:00+01:00'},
#   {'Id': 52172,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BTN',
#    'ParentLocationCode': 'SEAR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'South-East Asia',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2018,
#    'Dim1': 'SEX_FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '74.9 [74.3-75.6]',
#    'NumericValue': 74.94852418,
#    'Low': 74.30722839,
#    'High': 75.63214889,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2018',
#    'TimeDimensionBegin': '2018-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2018-12-31T00:00:00+01:00'},
#   {'Id': 53554,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ESP',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2001,
#    'Dim1': 'SEX_FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '82.8 [82.7-82.8]',
#    'NumericValue': 82.75513079,
#    'Low': 82.68677272,
#    'High': 82.82348886,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2001',
#    'TimeDimensionBegin': '2001-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2001-12-31T00:00:00+01:00'},
#   {'Id': 53580,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ZWE',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2021,
#    'Dim1': 'SEX_BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.5 [57.8-59.4]',
#    'NumericValue': 58.48102238,
#    'Low': 57.77939563,
#    'High': 59.3735111,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2021',
#    'TimeDimensionBegin': '2021-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2021-12-31T00:00:00+01:00'},
#   {'Id': 53601,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'NGA',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2020,
#    'Dim1': 'SEX_FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '64.4 [63.4-65.4]',
#    'NumericValue': 64.43518594,
#    'Low': 63.40696985,
#    'High': 65.38601771,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2020',
#    'TimeDimensionBegin': '2020-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2020-12-31T00:00:00+01:00'},
#   {'Id': 54245,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RUS',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2011,
#    'Dim1': 'SEX_BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '69.8 [69.8-69.8]',
#    'NumericValue': 69.77052933,
#    'Low': 69.75994142,
#    'High': 69.8325113,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2011',
#    'TimeDimensionBegin': '2011-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2011-12-31T00:00:00+01:00'},
#   {'Id': 54465,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'HTI',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2005,
#    'Dim1': 'SEX_BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.6 [57.8-59.6]',
#    'NumericValue': 58.63996581,
#    'Low': 57.83890036,
#    'High': 59.58483627,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2005',
#    'TimeDimensionBegin': '2005-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2005-12-31T00:00:00+01:00'},
# ...
#    'Low': 73.10887977,
#    'High': 73.51838084,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2014',
#    'TimeDimensionBegin': '2014-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2014-12-31T00:00:00+01:00'},
#   {'Id': 768069,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BRB',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2009,
#    'Dim1': 'SEX_MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '74.5 [74.3-74.8]',
#    'NumericValue': 74.5145213,
#    'Low': 74.26793145,
#    'High': 74.75778476,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2009',
#    'TimeDimensionBegin': '2009-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2009-12-31T00:00:00+01:00'},
#   {'Id': 768689,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RUS',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2004,
#    'Dim1': 'SEX_FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.2 [72.1-72.3]',
#    'NumericValue': 72.17452596,
#    'Low': 72.13808377,
#    'High': 72.28053631,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2004',
#    'TimeDimensionBegin': '2004-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2004-12-31T00:00:00+01:00'},
#   {'Id': 768949,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'LKA',
#    'ParentLocationCode': 'SEAR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'South-East Asia',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2010,
#    'Dim1': 'SEX_FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '78.3 [78.2-78.4]',
#    'NumericValue': 78.25157986,
#    'Low': 78.20774381,
#    'High': 78.36995351,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2010',
#    'TimeDimensionBegin': '2010-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2010-12-31T00:00:00+01:00'},
#   {'Id': 769071,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GUY',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2008,
#    'Dim1': 'SEX_BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '65.8 [65.2-66.3]',
#    'NumericValue': 65.75519494,
#    'Low': 65.19381124,
#    'High': 66.25667876,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2008',
#    'TimeDimensionBegin': '2008-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2008-12-31T00:00:00+01:00'},
#   {'Id': 769617,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'NZL',
#    'ParentLocationCode': 'WPR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2001,
#    'Dim1': 'SEX_MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '76.1 [76.1-76.2]',
#    'NumericValue': 76.11269921,
#    'Low': 76.08809126,
#    'High': 76.20120359,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2001',
#    'TimeDimensionBegin': '2001-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2001-12-31T00:00:00+01:00'},
#   {'Id': 769792,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'USA',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2010,
#    'Dim1': 'SEX_BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '78.6 [78.6-78.7]',
#    'NumericValue': 78.6069239,
#    'Low': 78.5592643,
#    'High': 78.65458351,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2010',
#    'TimeDimensionBegin': '2010-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2010-12-31T00:00:00+01:00'},
#   {'Id': 769930,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'SAU',
#    'ParentLocationCode': 'EMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Eastern Mediterranean',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2018,
#    'Dim1': 'SEX_MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '76.4 [76.1-76.8]',
#    'NumericValue': 76.42424095,
#    'Low': 76.10143061,
#    'High': 76.76688262,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2018',
#    'TimeDimensionBegin': '2018-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2018-12-31T00:00:00+01:00'},
#   {'Id': 771127,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'PRY',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2015,
#    'Dim1': 'SEX_FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '78.1 [77.7-78.7]',
#    'NumericValue': 78.09122069,
#    'Low': 77.6526758,
#    'High': 78.68642281,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2015',
#    'TimeDimensionBegin': '2015-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2015-12-31T00:00:00+01:00'},
#   {'Id': 771308,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'PNG',
#    'ParentLocationCode': 'WPR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2004,
#    'Dim1': 'SEX_FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '64.4 [63.8-65.2]',
#    'NumericValue': 64.39772383,
#    'Low': 63.77758373,
#    'High': 65.18140564,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2004',
#    'TimeDimensionBegin': '2004-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2004-12-31T00:00:00+01:00'},
#   {'Id': 771644,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'SLE',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2020,
#    'Dim1': 'SEX_FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.6 [60.6-62.8]',
#    'NumericValue': 61.59923854,
#    'Low': 60.56804972,
#    'High': 62.77923834,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2020',
#    'TimeDimensionBegin': '2020-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2020-12-31T00:00:00+01:00'},
#   {'Id': 772158,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'SOM',
#    'ParentLocationCode': 'EMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Eastern Mediterranean',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2015,
#    'Dim1': 'SEX_FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '56.0 [55.0-57.3]',
#    'NumericValue': 56.00187691,
#    'Low': 54.98094432,
#    'High': 57.26939497,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2015',
#    'TimeDimensionBegin': '2015-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2015-12-31T00:00:00+01:00'},
#   {'Id': 772369,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'KAZ',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2004,
#    'Dim1': 'SEX_FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '70.9 [70.7-71.2]',
#    'NumericValue': 70.94850579,
#    'Low': 70.7082963,
#    'High': 71.23043922,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2004',
#    'TimeDimensionBegin': '2004-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2004-12-31T00:00:00+01:00'},
#   {'Id': 772561,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'MAR',
#    'ParentLocationCode': 'EMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Eastern Mediterranean',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2007,
#    'Dim1': 'SEX_FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.3 [71.6-72.9]',
#    'NumericValue': 72.28505657,
#    'Low': 71.63905242,
#    'High': 72.90564663,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2007',
#    'TimeDimensionBegin': '2007-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2007-12-31T00:00:00+01:00'},
#   {'Id': 772790,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GEO',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2014,
#    'Dim1': 'SEX_MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '68.4 [68.2-68.6]',
#    'NumericValue': 68.35369007,
#    'Low': 68.16832223,
#    'High': 68.56161752,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2014',
#    'TimeDimensionBegin': '2014-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2014-12-31T00:00:00+01:00'},
#   {'Id': 773469,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'WORLDBANKINCOMEGROUP',
#    'SpatialDim': 'WB_UMI',
#    'ParentLocationCode': None,
#    'TimeDimType': 'YEAR',
#    'ParentLocation': None,
#    'Dim1Type': 'SEX',
#    'TimeDim': 2014,
#    'Dim1': 'SEX_BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '74.5 [74.3-75.0]',
#    'NumericValue': 74.53468804,
#    'Low': 74.25408972,
#    'High': 74.99161886,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2014',
#    'TimeDimensionBegin': '2014-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2014-12-31T00:00:00+01:00'},
#   {'Id': 773549,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'SRB',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2001,
#    'Dim1': 'SEX_FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '75.0 [74.8-75.1]',
#    'NumericValue': 74.95102091,
#    'Low': 74.81460817,
#    'High': 75.14039743,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2001',
#    'TimeDimensionBegin': '2001-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2001-12-31T00:00:00+01:00'},
#   {'Id': 775142,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'IRL',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2005,
#    'Dim1': 'SEX_MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '76.5 [76.5-76.6]',
#    'NumericValue': 76.51063315,
#    'Low': 76.48356856,
#    'High': 76.59933414,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2005',
#    'TimeDimensionBegin': '2005-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2005-12-31T00:00:00+01:00'},
#   {'Id': 776753,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'LVA',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2019,
#    'Dim1': 'SEX_MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '71.1 [70.9-71.2]',
#    'NumericValue': 71.0508773,
#    'Low': 70.9354437,
#    'High': 71.2081695,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2019',
#    'TimeDimensionBegin': '2019-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2019-12-31T00:00:00+01:00'},
#   {'Id': 777059,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'GLOBAL',
#    'SpatialDim': 'GLOBAL',
#    'ParentLocationCode': None,
#    'TimeDimType': 'YEAR',
#    'ParentLocation': None,
#    'Dim1Type': 'SEX',
#    'TimeDim': 2009,
#    'Dim1': 'SEX_MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '67.7 [67.2-68.0]',
#    'NumericValue': 67.6680326,
#    'Low': 67.23495017,
#    'High': 68.04735096,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2009',
#    'TimeDimensionBegin': '2009-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2009-12-31T00:00:00+01:00'},
#   {'Id': 777156,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'MNE',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2014,
#    'Dim1': 'SEX_BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '76.6 [76.5-76.8]',
#    'NumericValue': 76.62030337,
#    'Low': 76.50435037,
#    'High': 76.83640292,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2014',
#    'TimeDimensionBegin': '2014-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2014-12-31T00:00:00+01:00'},
#   {'Id': 777345,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ERI',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2003,
#    'Dim1': 'SEX_FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '60.7 [59.7-61.7]',
#    'NumericValue': 60.65082553,
#    'Low': 59.67474652,
#    'High': 61.66532519,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2003',
#    'TimeDimensionBegin': '2003-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2003-12-31T00:00:00+01:00'},
#   {'Id': 777816,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'IRL',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'TimeDim': 2015,
#    'Dim1': 'SEX_MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '79.3 [79.3-79.5]',
#    'NumericValue': 79.33847643,
#    'Low': 79.30956102,
#    'High': 79.46095222,
#    'Comments': None,
#    'Date': '2024-08-02T09:43:39.193+02:00',
#    'TimeDimensionValue': '2015',
#    'TimeDimensionBegin': '2015-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2015-12-31T00:00:00+01:00'},
#   ...]}

# %%
import seaborn as sns
import matplotlib.pyplot as plt

if 'value' in data:
    # Aplanar los datos
    df_vida = pd.json_normalize(data['value'])

    # Verifica qué nombres de columna están disponibles
    print(df_vida.columns.tolist())  # útil en clase también

    # Buscar equivalentes a 'Country' y 'TimeDim'
    columnas_posibles = ['SpatialDim', 'TimeDim', 'NumericValue']
    df_vida = df_vida[columnas_posibles]

    # Renombrar columnas
    df_vida.columns = ['pais', 'anio', 'esperanza_vida']
    df_vida = df_vida[df_vida['anio'] >= 2015]

    # Filtrar países
    paises = ['ECU', 'COL', 'PER']  # códigos ISO de países
    df_paises = df_vida[df_vida['pais'].isin(paises)]

    # Graficar
    sns.lineplot(data=df_paises, x='anio', y='esperanza_vida', hue='pais')
    plt.title('Evolución de la esperanza de vida (2015+)')
    plt.show()

else:
    print("No se encontraron datos en la API")
# Out:
# ['Id', 'IndicatorCode', 'SpatialDimType', 'SpatialDim', 'ParentLocationCode', 'TimeDimType', 'ParentLocation', 'Dim1Type', 'TimeDim', 'Dim1', 'Dim2Type', 'Dim2', 'Dim3Type', 'Dim3', 'DataSourceDimType', 'DataSourceDim', 'Value', 'NumericValue', 'Low', 'High', 'Comments', 'Date', 'TimeDimensionValue', 'TimeDimensionBegin', 'TimeDimensionEnd']

# %%
resumen_vida = df_vida.groupby('pais')['esperanza_vida'].mean().sort_values(ascending=False)
resumen_vida.head(10)
# Out:
# pais
# JPN    84.308345
# SGP    83.512563
# KOR    83.152042
# CHE    83.075652
# AUS    82.813349
# LUX    82.682646
# ESP    82.585821
# ITA    82.458153
# NOR    82.456397
# ISL    82.376187
# Name: esperanza_vida, dtype: float64
